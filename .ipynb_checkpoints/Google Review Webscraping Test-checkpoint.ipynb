# %% [markdown]
# ## More specific using selenium, javascript

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import random

# Load the website using a webdriver
driver = webdriver.Chrome()
driver.get("https://www.google.com/search?q=hornbach+baumarkt+bornheim&rlz=1C1GCEA_enDE869DE874&oq=hornbach+baumarkt+bornheim&aqs=chrome.0.35i39j46i175i199i512j0i22i30l7.3405j0j7&sourceid=chrome&ie=UTF-8#lrd=0x479651924a5cb4cf:0x23ca65292607c755,1,,,,")
# Wait for 4 seconds
time.sleep(4)

# Click on google consent
driver.find_element("xpath",'//*[@id="W0wltc"]').click()
# Wait for 5 seconds
time.sleep(random.randint(3,5))

# Click on sort by newest
driver.find_element("xpath",'/html/body/span[2]/g-lightbox/div/div[2]/div[3]/span/div/div/div/div[2]/div[3]/g-scrolling-carousel/div[1]/div/div[2]').click()
# Wait for 3 seconds
time.sleep(3)

# Find the total number of reviews and scroll down
total_number_of_reviews = driver.find_element("xpath",'//*[@id="gsr"]/span[2]/g-lightbox/div/div[2]/div[3]/span/div/div/div/div[1]/div[3]/div[1]/div/span/span').text.split(" ")[0]
total_number_of_reviews = int(total_number_of_reviews.replace('.','')) if '.' in total_number_of_reviews else int(total_number_of_reviews)

# Find scroll-element
scrollable_div = driver.find_element("xpath",'//*[@id="gsr"]/span[2]/g-lightbox/div/div[2]/div[3]/span/div/div/div/div[2]')
# NEED TO CHANGE 100 BACK TO 10 FOR ALL REVIEWS
for i in range(0,(round(total_number_of_reviews/40 - 1))):
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', 
                scrollable_div)
        time.sleep(random.randint(1,3))

# %%
for elements in driver.find_elements(By.CLASS_NAME, "review-more-link"):
    try:
        elements.click()
    except:
        pass

# %%
# wait for elements to load
time.sleep(10)

# extract the HTML using BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# do web scraping here

# # close the browser
# browser.close()

# %%
review_elements = soup.find_all('div', {'jscontroller': 'fIQYlf'})

# %%
# review_elements

# %%
# create empty lists to store the scraped data
dates = []
stars = []
reviews = []

# %%
# iterate through the review elements and extract the data
for review in review_elements:
    date = review.find('span', {'class': 'dehysf lTi8oc'}).text
    star = review.find('span', {'class': 'Fam1ne EBe2gf'})['aria-label']
    
    dates.append(date)
    stars.append(star)

# %%
# Reviews turn out to be tricky because they are hidden in different classes, so separate loop for them:

reviews = []
for review in review_elements:
    review_text = review.find('span', {'class': 'review-full-text'})
    if review_text:
        reviews.append(review_text.text)
    else:
        review_text = review.find('div', {'class': 'Jtu6Td'})
        if review_text:
            reviews.append(review_text.text)
        else:
            reviews.append('None')

# %%
# reviews

# %%
# Cleaning up the dates list

cleaned_dates = [date.replace("vor ", "").replace("\xa0", " ").replace("einem", "1").replace("einer", "1") for date in dates]
# print(cleaned_dates)

# %%
# Cleaning up the stars

cleaned_stars = [star.replace("Bewertung: ", "").replace(",0 von 5,", "") for star in stars]
# print(cleaned_stars)

# %% [markdown]
# ### Creating relative time columns for the "... time ago" values in cleaned_dates

# %%
import pandas as pd
dates_df = {'date': cleaned_dates}
dates_df = pd.DataFrame(dates_df)
# dates_df
# Out:
#         date
# 0      1 Tag
# 1      1 Tag
# 2    3 Tagen
# 3    3 Tagen
# 4    3 Tagen
# 5    3 Tagen
# 6    4 Tagen
# 7    4 Tagen
# 8    5 Tagen
# 9    6 Tagen
# 10   6 Tagen
# 11   1 Woche
# 12   1 Woche
# 13   1 Woche
# 14   1 Woche
# 15   1 Woche
# 16   1 Woche
# 17   1 Woche
# 18   1 Woche
# 19   1 Woche
# 20   1 Woche
# 21  2 Wochen
# 22  2 Wochen
# 23  2 Wochen
# 24  2 Wochen
# 25  2 Wochen
# 26  2 Wochen
# 27  2 Wochen
# 28  2 Wochen
# 29  2 Wochen
# 30  2 Wochen
# 31  2 Wochen
# 32  2 Wochen
# 33  2 Wochen
# 34  3 Wochen
# 35  3 Wochen
# 36  3 Wochen
# 37  3 Wochen
# 38  3 Wochen
# 39  3 Wochen
# 40  3 Wochen
# 41  3 Wochen
# 42  3 Wochen
# 43  3 Wochen
# 44  3 Wochen
# 45  3 Wochen
# 46  4 Wochen
# 47   1 Monat
# 48   1 Monat
# 49   1 Monat

# %%
# Defining function that calculates the timedelta for certain strings in the date column

from datetime import datetime, timedelta

def get_relative_datetime(time_string):
    current_time = datetime.now()
    time_dict = {"Stunde": timedelta(hours=1),
                 "Stunden": timedelta(hours=1),
                 "Tag": timedelta(days=1),
                 "Tagen": timedelta(days=1),
                 "Woche": timedelta(weeks=1),
                 "Wochen": timedelta(weeks=1),
                 "Monat": timedelta(days=30),
                 "Monaten": timedelta(days=30),
                 "Jahr": timedelta(days=365),
                 "Jahren": timedelta(days=365)}
    num, unit = time_string.split(" ")
    relative_time = current_time - int(num) * time_dict[unit]
    return relative_time

# Testing with hours, days, weeks, months and years (all available time-values)
print(get_relative_datetime("4 Stunden"))
print(get_relative_datetime("2 Tagen"))
print(get_relative_datetime("3 Wochen"))
print(get_relative_datetime("7 Monaten"))
print(get_relative_datetime("2 Jahren"))
# Out:
# 2023-01-31 06:57:32.063872
# 2023-01-29 10:57:32.063872
# 2023-01-10 10:57:32.063872
# 2022-07-05 10:57:32.063872
# 2021-01-31 10:57:32.063872

# %%
# Applying the function to all values in the date column and returning (overly specific) relative dates
dates_df["relative_dates"] = dates_df["date"].apply(get_relative_datetime)

# %%
# dates_df
# Out:
#         date             relative_dates
# 0      1 Tag 2023-01-30 10:57:32.095358
# 1      1 Tag 2023-01-30 10:57:32.095358
# 2    3 Tagen 2023-01-28 10:57:32.095358
# 3    3 Tagen 2023-01-28 10:57:32.095358
# 4    3 Tagen 2023-01-28 10:57:32.095358
# 5    3 Tagen 2023-01-28 10:57:32.095358
# 6    4 Tagen 2023-01-27 10:57:32.095358
# 7    4 Tagen 2023-01-27 10:57:32.095358
# 8    5 Tagen 2023-01-26 10:57:32.095358
# 9    6 Tagen 2023-01-25 10:57:32.095358
# 10   6 Tagen 2023-01-25 10:57:32.095358
# 11   1 Woche 2023-01-24 10:57:32.095358
# 12   1 Woche 2023-01-24 10:57:32.095358
# 13   1 Woche 2023-01-24 10:57:32.095358
# 14   1 Woche 2023-01-24 10:57:32.095358
# 15   1 Woche 2023-01-24 10:57:32.095358
# 16   1 Woche 2023-01-24 10:57:32.095358
# 17   1 Woche 2023-01-24 10:57:32.095358
# 18   1 Woche 2023-01-24 10:57:32.095358
# 19   1 Woche 2023-01-24 10:57:32.095358
# 20   1 Woche 2023-01-24 10:57:32.095358
# 21  2 Wochen 2023-01-17 10:57:32.095358
# 22  2 Wochen 2023-01-17 10:57:32.095358
# 23  2 Wochen 2023-01-17 10:57:32.095358
# 24  2 Wochen 2023-01-17 10:57:32.095358
# 26  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 27  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 28  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 29  2 Wochen 2023-01-17 10:57:32.095358    01/2023     2
# 30  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 31  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 32  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 33  2 Wochen 2023-01-17 10:57:32.095358    01/2023     5
# 34  3 Wochen 2023-01-10 10:57:32.095358    01/2023     5
# 35  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 36  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 37  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 38  3 Wochen 2023-01-10 10:57:32.095358    01/2023     5
# 39  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 40  3 Wochen 2023-01-10 10:57:32.095358    01/2023     5
# 41  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 42  3 Wochen 2023-01-10 10:57:32.095358    01/2023     1
# 43  3 Wochen 2023-01-10 10:57:32.095358    01/2023     5
# 44  3 Wochen 2023-01-10 10:57:32.095358    01/2023     4
# 45  3 Wochen 2023-01-10 10:57:32.095358    01/2023     5
# 46  4 Wochen 2023-01-03 10:57:32.095358    01/2023     5
# 47   1 Monat 2023-01-01 10:57:32.095358    01/2023     5
# 48   1 Monat 2023-01-01 10:57:32.095358    01/2023     5
# 49   1 Monat 2023-01-01 10:57:32.095358    01/2023     1
#
#                                                review
# 0   Man bekommt alles zu guten Preisen. Personal z...
# 1   Sehr freundliches und sehr kompetentes Persona...
# 2   Riesen großer Baumarkt gut sortiert mit Tankst...
# 3   wir sind seit Jahren Kunden mit Profikarte und...
# 4
# 5
# 6
# 7
# 8
# 9
# 10                 Hab alles gefunden auch ohne Hilfe
# 11
# 12  Eben Hornbach's Nummer 1 wenn da nichts geht w...
# 13
# 14  Mein Lieblingsbaumarkt , immer alles gut gelau...
# 15
# 16
# 17
# 18                 Hier wohnt Leidenschaft für DIY 🤩🛠
# 19                                      Hornbach eben
# 20  Bestellt online und zum Termin abgeholt. 5 Min...
# 21  Riesen Auswahl, top Service (bei den Elektroge...
# 22
# 23                                   Großes Sortiment
# 24
# 25  Riesen großer Markt, abgelegen, extra würde ic...
# 26  (Übersetzt von Google) Gut willkommen(Original...
# 27                 Definitiv der günstigste Baumarkt.
# 28  Ich hatte eine Twinkly Leuchte über den Kunden...
# 29                                         Naja......
# 30  Wie immer zielgerichtet zum Kaminholz. 6,25€ f...
# 31
# 32  Da bekommen wir fast alles. Und wenn wir Hilfe...
# 33                      Gutes Sortiment.Faire Preise.
# 34                      Der Baumarkt meiner Wahl.....
# 35
# 36
# 37
# 38                Hier findest Du immer das richtige.
# 39
# 40
# 41
# 42  Dieser Baumarkt ist leider dermaßen  unübersic...
# 43
# 44
# 45                    Gute Beratung elektro Abteilung
# 46
# 47  Zuschnitt online bestellt und hat hervorragend...
# 48
# 49

# %%
# df_full.head(-60)

# %%
# # create a dataframe to store the scraped data
# data = {'date': dates, 'stars': stars, 'review': reviews}
# df = pd.DataFrame(data)

# export the dataframe to a csv file
# df_full.to_csv('HORNBACH_Bornheim.csv', index=False)
