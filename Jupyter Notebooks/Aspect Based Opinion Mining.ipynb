# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import spacy
from sklearn.model_selection import train_test_split

# %% [markdown]
# # NLP

# %%
# Load data into pandas DataFrame
df = pd.read_csv('HORNBACH_Bornheim.csv')
df.head()
# Out:
#         date              relative_dates year_month  stars  \
# 0  4 Stunden  2023-01-31 13:07:29.691694    01/2023      4
# 1      1 Tag  2023-01-30 17:07:29.691694    01/2023      5
# 2      1 Tag  2023-01-30 17:07:29.691694    01/2023      5
# 3    3 Tagen  2023-01-28 17:07:29.691694    01/2023      5
# 4    3 Tagen  2023-01-28 17:07:29.691694    01/2023      4
#
#                                               review
# 0                                                NaN
# 1  Man bekommt alles zu guten Preisen. Personal z...
# 2  Sehr freundliches und sehr kompetentes Persona...
# 3  Riesen großer Baumarkt gut sortiert mit Tankst...
# 4  wir sind seit Jahren Kunden mit Profikarte und...

# %%
df['review'].isna().sum()
# Out:
# 1168

# %%
# Removing all reviews without text and storing in separate dataframe

df_text = df.dropna(subset=['review'])
df_text['review'].isna().sum()
# Out:
# 0

# %%
# Load german NLP model
nlp = spacy.load('de_core_news_sm')

# %%
import string
import re

def clean_text(text):
    
    # Remove emojis
    emoji_pattern = re.compile("["
        u"\U0001f600-\U0001f64f"  # emoticons
        u"\U0001f300-\U0001f5ff"  # symbols & pictographs
        u"\U0001f680-\U0001f6ff"  # transport & map symbols
        u"\U0001f1e0-\U0001f1ff"  # flags (iOS)
                            "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text)
    
    # Remove auto-translated parts
    parts = text.split("(Übersetzt von Google) ")
    if len(parts) >= 2:
        text = parts[1]
    else:
        text = parts[0]
    parts = text.split("(Original)")
    if len(parts) >= 2:
        text = parts[0]
        
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)
    
#     # This was in an earlier version of the code but the aspect term model already creates tokens
#     # Process the text using the Spacy NLP model
#     doc = nlp(text)
    
#     # Remove stop words
#     tokens = [token for token in doc if not token.is_stop]

#     # Lemmatize only verbs, nouns, and adjectives
#     lemmatized_tokens = [token.lemma_.lower() if token.pos_ in ['VERB', 'NOUN', 'ADJ'] else token.text.lower() for token in tokens]

#     # Join the lemmatized tokens back together into a single string

    return text

df_text['review_cleaned'] = df_text['review'].apply(clean_text)
df_text
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_2868\2010673145.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['review_cleaned'] = df_text['review'].apply(clean_text)
#           date              relative_dates year_month  stars  \
# 1        1 Tag  2023-01-30 17:07:29.691694    01/2023      5
# 2        1 Tag  2023-01-30 17:07:29.691694    01/2023      5
# 3      3 Tagen  2023-01-28 17:07:29.691694    01/2023      5
# 4      3 Tagen  2023-01-28 17:07:29.691694    01/2023      4
# 11     1 Woche  2023-01-24 17:07:29.691694    01/2023      5
# ...        ...                         ...        ...    ...
# 2188  3 Jahren  2020-02-01 17:07:29.709706    02/2020      4
# 2191  3 Jahren  2020-02-01 17:07:29.709706    02/2020      5
# 2195  3 Jahren  2020-02-01 17:07:29.709706    02/2020      4
# 2196  3 Jahren  2020-02-01 17:07:29.709706    02/2020      1
# 2198  3 Jahren  2020-02-01 17:07:29.709706    02/2020      4
#
#                                                  review  \
# 1     Man bekommt alles zu guten Preisen. Personal z...
# 2     Sehr freundliches und sehr kompetentes Persona...
# 3     Riesen großer Baumarkt gut sortiert mit Tankst...
# 4     wir sind seit Jahren Kunden mit Profikarte und...
# 11                   Hab alles gefunden auch ohne Hilfe
# ...                                                 ...
# 2188                                                Gut
# 2191                                           Sehr gut
# 2195  immer wieder nützlich, leider wird das Angebot...
# 2196             Deutschlands unfreundlichster Baumarkt
# 2198                                       Hätten alles
#
#                                          review_cleaned
# 1     Man bekommt alles zu guten Preisen Personal zu...
# 2     Sehr freundliches und sehr kompetentes Persona...
# 3     Riesen großer Baumarkt gut sortiert mit Tankst...
# 4     wir sind seit Jahren Kunden mit Profikarte und...
# 11                   Hab alles gefunden auch ohne Hilfe
# ...                                                 ...
# 2188                                                Gut
# 2191                                           Sehr gut
# 2195  immer wieder nützlich leider wird das Angebot ...
# 2196             Deutschlands unfreundlichster Baumarkt
# 2198                                       Hätten alles
#
# [1032 rows x 6 columns]

# %%
# # Dropping NaN's of tokenized column
# df_text = df_text.dropna(subset=['review_tokenized'])
# print(df_text['review_tokenized'].isna().sum())
# print(df_text.shape)

# %% [markdown]
# # Aspect based sentiment analysis

# %% [markdown]
# ## Extract aspect terms and classify sentiments

# %%
from pyabsa import AspectTermExtraction as ATEPC, available_checkpoints

# you can view all available checkpoints by calling available_checkpoints()
checkpoint_map = available_checkpoints()

aspect_extractor = ATEPC.AspectExtractor('multilingual',
                                         auto_device=False,  # False means load model on CPU
                                         cal_perplexity=True,
                                         )

inference_source = list(df_text['review_cleaned'])
atepc_result = aspect_extractor.batch_predict(target_file=inference_source,  #
                                              save_result=True,
                                              print_result=True,  # print the result
                                              pred_sentiment=True,  # Predict the sentiment of extracted aspect terms
                                              )

print(atepc_result)
# Out:
# [2023-02-02 12:08:17] (2.0.27) Please specify the task code, e.g. from pyabsa import TaskCodeOption
# [2023-02-02 12:08:18] (2.0.27) Load aspect extractor from checkpoints\ATEPC_MULTILINGUAL_CHECKPOINT
# [2023-02-02 12:08:18] (2.0.27) config: checkpoints\ATEPC_MULTILINGUAL_CHECKPOINT\fast_lcf_atepc.config
# [2023-02-02 12:08:18] (2.0.27) state_dict: checkpoints\ATEPC_MULTILINGUAL_CHECKPOINT\fast_lcf_atepc.state_dict
# [2023-02-02 12:08:18] (2.0.27) model: None
# [2023-02-02 12:08:18] (2.0.27) tokenizer: checkpoints\ATEPC_MULTILINGUAL_CHECKPOINT\fast_lcf_atepc.tokenizer
# [2023-02-02 12:08:18] (2.0.27) Set Model Device: cpu
# [2023-02-02 12:08:18] (2.0.27) Device Name: Unknown
# Some weights of the model checkpoint at microsoft/mdeberta-v3-base were not used when initializing DebertaV2Model: ['lm_predictions.lm_head.LayerNorm.bias', 'mask_predictions.dense.weight', 'lm_predictions.lm_head.dense.bias', 'lm_predictions.lm_head.dense.weight', 'mask_predictions.classifier.bias', 'lm_predictions.lm_head.bias', 'mask_predictions.LayerNorm.bias', 'mask_predictions.classifier.weight', 'mask_predictions.dense.bias', 'mask_predictions.LayerNorm.weight', 'lm_predictions.lm_head.LayerNorm.weight']
# - This IS expected if you are initializing DebertaV2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DebertaV2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# C:\Users\a\anaconda3\lib\site-packages\transformers\convert_slow_tokenizer.py:446: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preparing apc inference dataloader: 100%|██████████| 1032/1032 [00:01<00:00, 559.92it/s]
# extracting aspect terms: 100%|██████████| 33/33 [02:06<00:00,  3.85s/it]
# preparing apc inference dataloader: 100%|██████████| 934/934 [00:02<00:00, 419.05it/s]
# classifying aspect sentiments:   0%|          | 0/30 [00:00<?, ?it/s]C:\Users\a\AppData\Roaming\Python\Python39\site-packages\pyabsa\tasks\AspectTermExtraction\prediction\aspect_extractor.py:651: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   float(x) for x in F.softmax(i_apc_logits).cpu().numpy().tolist()
# classifying aspect sentiments: 100%|██████████| 30/30 [02:08<00:00,  4.30s/it]
# [2023-02-02 12:12:58] (2.0.27) The results of aspect term extraction have been saved in C:\Users\a\Google Drive\IRONHACK Data Analysis Bootcamp\Final Project full\Aspect Term Extraction and Polarity Classification.FAST_LCF_ATEPC.result.json
# [2023-02-02 12:12:58] (2.0.27) Example 0: Man bekommt alles zu guten <Preisen Personal:Positive Confidence:0.996209979057312> zuvorkommend <Parkplätze:Positive Confidence:0.9825524091720581> auch genügend Neuerdings eine Currybude auf dem Parkplatz Mit die beste Currywurst in Karlsruhe
# [2023-02-02 12:12:58] (2.0.27) Example 1: Sehr freundliches und sehr kompetentes <Personal:Positive Confidence:0.9974580407142639> Wir informierten uns über Wandfliesen deren Möglichkeiten zur Verlegung und danach ließen wir uns über den Einbau einer Dusche beraten und wurden an beiden Stellen perfekt und fachkundig beraten
# [2023-02-02 12:12:58] (2.0.27) Example 2: Riesen großer <Baumarkt:Positive Confidence:0.9972350001335144> gut sortiert mit Tankstelle
# [2023-02-02 12:12:58] (2.0.27) Example 3: wir sind seit Jahren Kunden mit Profikarte und bekommen keine Ermäßigung wie bei der Konkurrenz irgendwie schadeda sollte sich die Marktleitung was einfallen lassen es ist unser <Baumarkt:Positive Confidence:0.9972508549690247> des Vertrauens bekommen immer was wir benötigen die <Beratung:Positive Confidence:0.9977661371231079> vom <Personal:Positive Confidence:0.99750816822052> ist sehr gut Können wir mit gutem Gewissen weiter empfehlen weiter so
# [2023-02-02 12:12:58] (2.0.27) Example 4: Hab alles gefunden auch ohne Hilfe
# [2023-02-02 12:12:58] (2.0.27) Example 5: Eben <Hornbachs:Negative Confidence:0.966265857219696> Nummer wenn da nichts geht wo sonst
# [2023-02-02 12:12:58] (2.0.27) Example 6: Mein Lieblingsbaumarkt immer alles gut gelaufen
# [2023-02-02 12:12:58] (2.0.27) Example 7: Hier wohnt Leidenschaft für DIY
# [2023-02-02 12:12:58] (2.0.27) Example 8: Hornbach eben
# [2023-02-02 12:12:58] (2.0.27) Example 9: Bestellt online und zum Termin abgeholt Min <Wartezeit:Positive Confidence:0.9984174966812134> super
# [2023-02-02 12:12:58] (2.0.27) Example 10: Riesen <Auswahl:Positive Confidence:0.9984999895095825> top <Service:Positive Confidence:0.9979897737503052> bei den Elektrogeräten Schleifern etc wurde ich immer top beraten Äußerst kulant in ReklamationsfällenZuschnitte passen immer
# [2023-02-02 12:12:58] (2.0.27) Example 11: Großes Sortiment
# [2023-02-02 12:12:58] (2.0.27) Example 12: Riesen großer <Markt:Negative Confidence:0.996024489402771> abgelegen extra würde ich da nicht hinfahren
# [2023-02-02 12:12:58] (2.0.27) Example 13: Gut willkommen
# [2023-02-02 12:12:58] (2.0.27) Example 14: Definitiv der günstigste Baumarkt
# [2023-02-02 12:12:58] (2.0.27) Example 15: Ich hatte eine Twinkly Leuchte über den <Kundenservice:Positive Confidence:0.45395809412002563> reklamiert Die Leuchte war kein Jahr alt Hornbach hat mir ohne wenn und aber eine kostenlose Ersatzbestellung zugeschickt Innerhalb von drei Tagen war die neue Leuchte da Vielen Dank für den super Service
# [2023-02-02 12:12:58] (2.0.27) Example 16: Naja
# [2023-02-02 12:12:58] (2.0.27) Example 17: Wie immer zielgerichtet zum Kaminholz für kg ist gefühlt Wucher jedoch für die RUF Qualität in Landau immer noch irgendwie günstig Hornbach hat jedenfalls immer gute Preise
# [2023-02-02 12:12:58] (2.0.27) Example 18: Da bekommen wir fast alles Und wenn wir Hilfe benötigen dann ist immer jemand dader uns beraten kann Von mir die Sterne
# [2023-02-02 12:12:58] (2.0.27) Example 19: Gutes SortimentFaire Preise
# [2023-02-02 12:12:58] (2.0.27) Example 20: Der <Baumarkt:Positive Confidence:0.9977965354919434> meiner Wahl
# [2023-02-02 12:12:58] (2.0.27) Example 21: Hier findest Du immer das richtige
# [2023-02-02 12:12:58] (2.0.27) Example 22: Dieser Baumarkt ist leider dermaßen unübersichtlich und unaufgeräumt Die Gänge wirken eng und dunkel und manche Abteilungen geben ein sehr chaotisches Bild ab bspw die MotorGartengeräteIn vielen Abteilungen liegen oftmals in den Regalen Produkte nicht richtig sortiert und sehen aus wie hingeschmissen oder die Bepreisung ist nicht eindeutig da mehrere ähnliche Produkte unsortiert beisammen liegen Gleichzeitig wirken Kartons bzw Artikel lieblos abgestellt und gestapeltWurde leider schon mehrfach enttäuscht und habe den Markt entnervt verlassen Da auch viel Zeit mit Suchen verbracht werden mussteFür mich ist es nicht nachvollziehbar dass Hornbach nicht mehr wert auf eine gutes Erscheinungsbild legt zumal sich in Bornheim die Zentrale befindetLeider echt kein Vergleich zum Ambiente und der Ordnung bei der Konkurrenz in Landau Besuche den Hornbach nur da dort die Preise teilweise um einiges besser sind
# [2023-02-02 12:12:58] (2.0.27) Example 23: Gute <Beratung:Positive Confidence:0.9888933300971985> elektro Abteilung
# [2023-02-02 12:12:58] (2.0.27) Example 24: Zuschnitt online bestellt und hat hervorragend geklappt Es wirkt etwas unaufgeräumt aber die <Mitarbeiter:Positive Confidence:0.9919548630714417> sind sehr hilfsbereit und man findet spätestens mit deren Hilfe alles
# [2023-02-02 12:12:58] (2.0.27) Example 25: Freundliches Personal
# [2023-02-02 12:12:58] (2.0.27) Example 26: Riesige Auswahl geschultes freundliches <Personal:Positive Confidence:0.9992291927337646> alles unter einem Dach Hier findet man fast alles was das <Handwerker:Positive Confidence:0.9977138042449951> Herz höher schlagen lässt
# [2023-02-02 12:12:58] (2.0.27) Example 47: Das beste <Sortiment:Positive Confidence:0.9992024302482605> und die größte <Auswahl:Positive Confidence:0.9989452958106995> weit und breit Nicht zu toppenMit dem <Drive:Positive Confidence:0.9907693266868591> super bequem für Baustoffe Und dazu sehr preiswerte <Tankstelle:Positive Confidence:0.9941387176513672> direkt dabei
# [2023-02-02 12:12:58] (2.0.27) Example 48: Also ich bin an sich zufrieden mit hornbach Jedoch in Bereich Schreinerei ist KEIN Kompetentes Personal zu finden sie können weder Technische Zeichnungen noch Normale Zeichnungen lesen richtige Maße bestimmen und beraten Aus diesem Grund Sterne Verbesserung Vorschlag Schulung Mathematik Maße berechnen Zeichnungen Skizze Pläne lesen und verstehen Räumliches Verständnis logisches Denken verbessern der Kunden BeratungFalls dies nicht möglich ist bitte ich drum keine Werbung für Fachpersonal zu machen wen diese nicht gegeben ist im Bereich Schreiner Bornheim Landau
# [2023-02-02 12:12:58] (2.0.27) Example 49: Die Freundlichkeit des <Personals:Negative Confidence:0.994971513748169> lässt zu wünschen übrig wenn man zu einem Kunden zB sagt wenn sie das haben wollen bestellen Sie es im Internet welche Sprache ist das A möchte ich was verkaufen oder es sollte zu Hause bleiben und nicht so eine Betrieb arbeiten
# [2023-02-02 12:12:58] (2.0.27) Example 50: Top Arbeitgeber
# [2023-02-02 12:12:58] (2.0.27) Example 51: Auch in Bornheim ist das <Personal:Positive Confidence:0.9987106323242188> sehr Fachwissend und freundlich da steht man nicht lange ohne Beratung herum Super macht weiter so sehr zu empfehlen
# [2023-02-02 12:12:58] (2.0.27) Example 52: Großer und gut ausgestatteter Baumarkt
# [2023-02-02 12:12:58] (2.0.27) Example 53: Habe ich die Wahl zwischen Obi und Hagebau gehe ich nur zu HornbachDas hat sich auch nach Jahren nicht geändert Baumärkte die Kaffee Wein Zeitschriften Bücher Süßwaren etc verkaufen sind mir suspekt
# [2023-02-02 12:12:58] (2.0.27) Example 54: Nur noch Hornbach gute Beratung
# [2023-02-02 12:12:58] (2.0.27) Example 55: Alle <baustoffe:Positive Confidence:0.9986598491668701> sehr günstig und gutAlle Werzeug jahre garantie
# [2023-02-02 12:12:58] (2.0.27) Example 56: Mitarbeiter die man immer fragen kannfinde ich großartig Ich habe nach Autozubehör gefragtgenau nach H Birnen Nachdem ich in verschiedenen Gängen gesucht habe in die ich geschickt wurde bin ich frustriert nach Hause gefahren
# [2023-02-02 12:12:58] (2.0.27) Example 57: Tolle <Mitarbeiter marktleitung:Positive Confidence:0.9991937279701233> sehr nett und freundlich
# [2023-02-02 12:12:58] (2.0.27) Example 58: Hornbach ist halt Hornbach super <Service:Positive Confidence:0.9977377653121948> und freundliches <Personal:Positive Confidence:0.9982581734657288> Online bestellen auf den nächsten Tag war aber alles schon am selben Tag abholbereit
# [2023-02-02 12:12:58] (2.0.27) Example 59: Großer Baumarkt mit umfangreichen <Sortiment:Positive Confidence:0.9981040954589844> und freundlichem Personal
# [2023-02-02 12:12:58] (2.0.27) Example 1010: Gerne wieder
# [2023-02-02 12:12:58] (2.0.27) Example 1011: Für <bastler:Positive Confidence:0.9757000207901001> und Handwerker auch für Kleingärtner sehr gut
# [2023-02-02 12:12:58] (2.0.27) Example 1012: Man bekommt was man braucht mansche helfen sofort aber die meisten sind hier nicht zuständig
# [2023-02-02 12:12:58] (2.0.27) Example 1013: Sehr schön und riesen Auswahl
# [2023-02-02 12:12:58] (2.0.27) Example 1014: Mehrere spezielle <Muttern:Neutral Confidence:0.6738765835762024> und <Schrauben:Neutral Confidence:0.6785193085670471> benötigt und nur hier gefunden
# [2023-02-02 12:12:58] (2.0.27) Example 1015: Mein Baumarkt
# [2023-02-02 12:12:58] (2.0.27) Example 1016: Auswahl auf dem <sonntagsflohmarkt:Positive Confidence:0.9866918921470642> war schon vielfältiger
# [2023-02-02 12:12:58] (2.0.27) Example 1017: Eine ganz wunderbare Auswahl an Blumen
# [2023-02-02 12:12:58] (2.0.27) Example 1018: Riesig
# [2023-02-02 12:12:58] (2.0.27) Example 1019: Hervorragende Preise
# [2023-02-02 12:12:58] (2.0.27) Example 1020: Lieblings Baumarkt
# [2023-02-02 12:12:58] (2.0.27) Example 1021: Immer sehr freundlich und kompetent Beratung
# [2023-02-02 12:12:58] (2.0.27) Example 1022: Gut
# [2023-02-02 12:12:58] (2.0.27) Example 1023: Da findet man alles
# [2023-02-02 12:12:58] (2.0.27) Example 1024: Central OfficeÜbersetzt von GoogleHauptbüro
# [2023-02-02 12:12:58] (2.0.27) Example 1025: Sehr freundliche <Verkäufer:Positive Confidence:0.9992185831069946> und gute <Stimmung:Positive Confidence:0.9991604089736938> dort
# [2023-02-02 12:12:58] (2.0.27) Example 1026: Es gibt alles was mich für dein <Zuhause:Positive Confidence:0.991733193397522> verantwortlich macht
# [2023-02-02 12:12:58] (2.0.27) Example 1027: Gut
# [2023-02-02 12:12:58] (2.0.27) Example 1028: Sehr gut
# [2023-02-02 12:12:58] (2.0.27) Example 1029: immer wieder nützlich leider wird das <Angebot:Negative Confidence:0.9964744448661804> immer mehr reduziert
# [2023-02-02 12:12:58] (2.0.27) Example 1030: Deutschlands unfreundlichster Baumarkt
# [2023-02-02 12:12:58] (2.0.27) Example 1031: Hätten alles
# [{'sentence': 'Man bekommt alles zu guten Preisen Personal zuvorkommend Parkplätze auch genügend Neuerdings eine Currybude auf dem Parkplatz Mit die beste Currywurst in Karlsruhe', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'I-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['Man', 'bekommt', 'alles', 'zu', 'guten', 'Preisen', 'Personal', 'zuvorkommend', 'Parkplätze', 'auch', 'genügend', 'Neuerdings', 'eine', 'Currybude', 'auf', 'dem', 'Parkplatz', 'Mit', 'die', 'beste', 'Currywurst', 'in', 'Karlsruhe'], 'aspect': ['Preisen Personal', 'Parkplätze'], 'position': [[6, 7], [9]], 'sentiment': ['Positive', 'Positive'], 'probs': [[0.0004890267737209797, 0.0033010474871844053, 0.996209979057312], [0.0009945188648998737, 0.01645307056605816, 0.9825524091720581]], 'confidence': [0.996209979057312, 0.9825524091720581]}, {'sentence': 'Sehr freundliches und sehr kompetentes Personal Wir informierten uns über Wandfliesen deren Möglichkeiten zur Verlegung und danach ließen wir uns über den Einbau einer Dusche beraten und wurden an beiden Stellen perfekt und fachkundig beraten', 'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['Sehr', 'freundliches', 'und', 'sehr', 'kompetentes', 'Personal', 'Wir', 'informierten', 'uns', 'über', 'Wandfliesen', 'deren', 'Möglichkeiten', 'zur', 'Verlegung', 'und', 'danach', 'ließen', 'wir', 'uns', 'über', 'den', 'Einbau', 'einer', 'Dusche', 'beraten', 'und', 'wurden', 'an', 'beiden', 'Stellen', 'perfekt', 'und', 'fachkundig', 'beraten'], 'aspect': ['Personal'], 'position': [[6]], 'sentiment': ['Positive'], 'probs': [[0.00030488520860671997, 0.0022370878141373396, 0.9974580407142639]], 'confidence': [0.9974580407142639]}, {'sentence': 'Riesen großer Baumarkt gut sortiert mit Tankstelle', 'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP'], 'tokens': ['Riesen', 'großer', 'Baumarkt', 'gut', 'sortiert', 'mit', 'Tankstelle'], 'aspect': ['Baumarkt', 'Tankstelle'], 'position': [[3], [7]], 'sentiment': ['Positive', 'Positive'], 'probs': [[0.0009226521942764521, 0.0018423969158902764, 0.9972350001335144], [0.001742580090649426, 0.11718174070119858, 0.8810756802558899]], 'confidence': [0.9972350001335144, 0.8810756802558899]}, {'sentence': 'wir sind seit Jahren Kunden mit Profikarte und bekommen keine Ermäßigung wie bei der Konkurrenz irgendwie schadeda sollte sich die Marktleitung was einfallen lassen es ist unser Baumarkt des Vertrauens bekommen immer was wir benötigen die Beratung vom Personal ist sehr gut Können wir mit gutem Gewissen weiter empfehlen weiter so', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], 'tokens': ['wir', 'sind', 'seit', 'Jahren', 'Kunden', 'mit', 'Profikarte', 'und', 'bekommen', 'keine', 'Ermäßigung', 'wie', 'bei', 'der', 'Konkurrenz', 'irgendwie', 'schadeda', 'sollte', 'sich', 'die', 'Marktleitung', 'was', 'einfallen', 'lassen', 'es', 'ist', 'unser', 'Baumarkt', 'des', 'Vertrauens', 'bekommen', 'immer', 'was', 'wir', 'benötigen', 'die', 'Beratung', 'vom', 'Personal', 'ist', 'sehr', 'gut', 'Können', 'wir', 'mit', 'gutem', 'Gewissen', 'weiter', 'empfehlen', 'weiter', 'so'], 'aspect': ['Baumarkt', 'Beratung', 'Personal'], 'position': [[28], [37], [39]], 'sentiment': ['Positive', 'Positive', 'Positive'], 'probs': [[0.0014066078001633286, 0.0013425510842353106, 0.9972508549690247], [0.0008501287666149437, 0.0013836824800819159, 0.9977661371231079], [0.0009402782307006419, 0.0015515212435275316, 0.99750816822052]], 'confidence': [0.9972508549690247, 0.9977661371231079, 0.99750816822052]}, {'sentence': 'Hab alles gefunden auch ohne Hilfe', 'IOB': ['O', 'O', 'O', 'O', 'O', 'O'], ...

# %%
# display(atepc_result)
# Out:
# [{'sentence': 'Man bekommt alles zu guten Preisen Personal zuvorkommend Parkplätze auch genügend Neuerdings eine Currybude auf dem Parkplatz Mit die beste Currywurst in Karlsruhe',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'I-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Man',
#    'bekommt',
#    'alles',
#    'zu',
#    'guten',
#    'Preisen',
#    'Personal',
#    'zuvorkommend',
#    'Parkplätze',
#    'auch',
#    'genügend',
#    'Neuerdings',
#    'eine',
#    'Currybude',
#    'auf',
#    'dem',
#    'Parkplatz',
#    'Mit',
#    'die',
#    'beste',
#    'Currywurst',
#    'in',
#    'Karlsruhe'],
#   'aspect': ['Preisen Personal', 'Parkplätze'],
#   'position': [[6, 7], [9]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0004890267737209797, 0.0033010474871844053, 0.996209979057312],
#    [0.0009945188648998737, 0.01645307056605816, 0.9825524091720581]],
#   'confidence': [0.996209979057312, 0.9825524091720581]},
#  {'sentence': 'Sehr freundliches und sehr kompetentes Personal Wir informierten uns über Wandfliesen deren Möglichkeiten zur Verlegung und danach ließen wir uns über den Einbau einer Dusche beraten und wurden an beiden Stellen perfekt und fachkundig beraten',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Sehr',
#    'freundliches',
#    'und',
#    'sehr',
#    'kompetentes',
#    'Personal',
#    'Wir',
#    'informierten',
#    'uns',
#    'über',
#    'Wandfliesen',
#    'deren',
#    'Möglichkeiten',
#    'zur',
#    'Verlegung',
#    'und',
#    'danach',
#    'ließen',
#    'wir',
#    'uns',
#    'über',
#    'den',
#    'Einbau',
#    'einer',
#    'Dusche',
#    'beraten',
#    'und',
#    'wurden',
#    'an',
#    'beiden',
#    'Stellen',
#    'perfekt',
#    'und',
#    'fachkundig',
#    'beraten'],
#   'aspect': ['Personal'],
#   'position': [[6]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00030488520860671997,
#     0.0022370878141373396,
#     0.9974580407142639]],
#   'confidence': [0.9974580407142639]},
#  {'sentence': 'Riesen großer Baumarkt gut sortiert mit Tankstelle',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Riesen',
#    'großer',
#    'Baumarkt',
#    'gut',
#    'sortiert',
#    'mit',
#    'Tankstelle'],
#   'aspect': ['Baumarkt', 'Tankstelle'],
#   'position': [[3], [7]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0009226521942764521, 0.0018423969158902764, 0.9972350001335144],
#    [0.001742580090649426, 0.11718174070119858, 0.8810756802558899]],
#   'confidence': [0.9972350001335144, 0.8810756802558899]},
#  {'sentence': 'wir sind seit Jahren Kunden mit Profikarte und bekommen keine Ermäßigung wie bei der Konkurrenz irgendwie schadeda sollte sich die Marktleitung was einfallen lassen es ist unser Baumarkt des Vertrauens bekommen immer was wir benötigen die Beratung vom Personal ist sehr gut Können wir mit gutem Gewissen weiter empfehlen weiter so',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['wir',
#    'sind',
#    'seit',
#    'Jahren',
#    'Kunden',
#    'mit',
#    'Profikarte',
#    'und',
#    'bekommen',
#    'keine',
#    'Ermäßigung',
#    'wie',
#    'bei',
#    'der',
#    'Konkurrenz',
#    'irgendwie',
#    'schadeda',
#    'sollte',
#    'sich',
#    'die',
#    'Marktleitung',
#    'was',
#    'einfallen',
#    'lassen',
#    'es',
#    'ist',
#    'unser',
#    'Baumarkt',
#    'des',
#    'Vertrauens',
#    'bekommen',
#    'immer',
#    'was',
#    'wir',
#    'benötigen',
#    'die',
#    'Beratung',
#    'vom',
#    'Personal',
#    'ist',
#    'sehr',
#    'gut',
#    'Können',
#    'wir',
#    'mit',
#    'gutem',
#    'Gewissen',
#    'weiter',
#    'empfehlen',
#    'weiter',
#    'so'],
#   'aspect': ['Baumarkt', 'Beratung', 'Personal'],
#   'position': [[28], [37], [39]],
#   'sentiment': ['Positive', 'Positive', 'Positive'],
#   'probs': [[0.0014066078001633286, 0.0013425510842353106, 0.9972508549690247],
#    [0.0008501287666149437, 0.0013836824800819159, 0.9977661371231079],
#    [0.0009402782307006419, 0.0015515212435275316, 0.99750816822052]],
#   'confidence': [0.9972508549690247, 0.9977661371231079, 0.99750816822052]},
#  {'sentence': 'Hab alles gefunden auch ohne Hilfe',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hab', 'alles', 'gefunden', 'auch', 'ohne', 'Hilfe'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Eben Hornbachs Nummer wenn da nichts geht wo sonst',
#   'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Eben',
#    'Hornbachs',
#    'Nummer',
#    'wenn',
#    'da',
#    'nichts',
#    'geht',
#    'wo',
#    'sonst'],
#   'aspect': ['Hornbachs'],
#   'position': [[2]],
#   'sentiment': ['Negative'],
#   'probs': [[0.966265857219696, 0.01968054659664631, 0.014053654856979847]],
#   'confidence': [0.966265857219696]},
#  {'sentence': 'Mein Lieblingsbaumarkt immer alles gut gelaufen',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Mein', 'Lieblingsbaumarkt', 'immer', 'alles', 'gut', 'gelaufen'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Hier wohnt Leidenschaft für DIY',
#   'IOB': ['O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hier', 'wohnt', 'Leidenschaft', 'für', 'DIY'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Hornbach eben',
#   'IOB': ['O', 'O'],
#   'tokens': ['Hornbach', 'eben'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Bestellt online und zum Termin abgeholt Min Wartezeit super',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP', 'O'],
#   'tokens': ['Bestellt',
#    'online',
#    'und',
#    'zum',
#    'Termin',
#    'abgeholt',
#    'Min',
#    'Wartezeit',
#    'super'],
#   'aspect': ['Wartezeit'],
#   'position': [[8]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0008755571907386184, 0.000706952007021755, 0.9984174966812134]],
#   'confidence': [0.9984174966812134]},
#  {'sentence': 'Riesen Auswahl top Service bei den Elektrogeräten Schleifern etc wurde ich immer top beraten Äußerst kulant in ReklamationsfällenZuschnitte passen immer',
#   'IOB': ['O',
#    'B-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Riesen',
#    'Auswahl',
#    'top',
#    'Service',
#    'bei',
#    'den',
#    'Elektrogeräten',
#    'Schleifern',
#    'etc',
#    'wurde',
#    'ich',
#    'immer',
#    'top',
#    'beraten',
#    'Äußerst',
#    'kulant',
#    'in',
#    'ReklamationsfällenZuschnitte',
#    'passen',
#    'immer'],
#   'aspect': ['Auswahl', 'Service'],
#   'position': [[2], [4]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0006778172682970762, 0.0008222609758377075, 0.9984999895095825],
#    [0.0006375628290697932, 0.0013726868201047182, 0.9979897737503052]],
#   'confidence': [0.9984999895095825, 0.9979897737503052]},
#  {'sentence': 'Großes Sortiment',
#   'IOB': ['O', 'B-ASP'],
#   'tokens': ['Großes', 'Sortiment'],
#   'aspect': ['Sortiment'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00041482032975181937,
#     0.0003432073281146586,
#     0.9992419481277466]],
#   'confidence': [0.9992419481277466]},
#  {'sentence': 'Riesen großer Markt abgelegen extra würde ich da nicht hinfahren',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Riesen',
#    'großer',
#    'Markt',
#    'abgelegen',
#    'extra',
#    'würde',
#    'ich',
#    'da',
#    'nicht',
#    'hinfahren'],
#   'aspect': ['Markt'],
#   'position': [[3]],
#   'sentiment': ['Negative'],
#   'probs': [[0.996024489402771, 0.0016906879609450698, 0.002284776186570525]],
#   'confidence': [0.996024489402771]},
#  {'sentence': 'Gut willkommen',
#   'IOB': ['O', 'O'],
#   'tokens': ['Gut', 'willkommen'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Definitiv der günstigste Baumarkt',
#   'IOB': ['O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Definitiv', 'der', 'günstigste', 'Baumarkt'],
#   'aspect': ['Baumarkt'],
#   'position': [[4]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0017933276249095798,
#     0.0002693397691473365,
#     0.9979373216629028]],
#   'confidence': [0.9979373216629028]},
#  {'sentence': 'Ich hatte eine Twinkly Leuchte über den Kundenservice reklamiert Die Leuchte war kein Jahr alt Hornbach hat mir ohne wenn und aber eine kostenlose Ersatzbestellung zugeschickt Innerhalb von drei Tagen war die neue Leuchte da Vielen Dank für den super Service',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP'],
#   'tokens': ['Ich',
#    'hatte',
#    'eine',
#    'Twinkly',
#    'Leuchte',
#    'über',
#    'den',
#    'Kundenservice',
#    'reklamiert',
#    'Die',
#    'Leuchte',
#    'war',
#    'kein',
#    'Jahr',
#    'alt',
#    'Hornbach',
#    'hat',
#    'mir',
#    'ohne',
#    'wenn',
#    'und',
#    'aber',
#    'eine',
#    'kostenlose',
#    'Ersatzbestellung',
#    'zugeschickt',
#    'Innerhalb',
#    'von',
#    'drei',
#    'Tagen',
#    'war',
#    'die',
#    'neue',
#    'Leuchte',
#    'da',
#    'Vielen',
#    'Dank',
#    'für',
#    'den',
#    'super',
#    'Service'],
#   'aspect': ['Kundenservice', 'Service'],
#   'position': [[8], [41]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.3992151618003845, 0.14682672917842865, 0.45395809412002563],
#    [0.012965972535312176, 0.012016485445201397, 0.9750174880027771]],
#   'confidence': [0.45395809412002563, 0.9750174880027771]},
#  {'sentence': 'Naja',
#   'IOB': ['O'],
#   'tokens': ['Naja'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Wie immer zielgerichtet zum Kaminholz für kg ist gefühlt Wucher jedoch für die RUF Qualität in Landau immer noch irgendwie günstig Hornbach hat jedenfalls immer gute Preise',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP'],
#   'tokens': ['Wie',
#    'immer',
#    'zielgerichtet',
#    'zum',
#    'Kaminholz',
#    'für',
#    'kg',
#    'ist',
#    'gefühlt',
#    'Wucher',
#    'jedoch',
#    'für',
#    'die',
#    'RUF',
#    'Qualität',
#    'in',
#    'Landau',
#    'immer',
#    'noch',
#    'irgendwie',
#    'günstig',
#    'Hornbach',
#    'hat',
#    'jedenfalls',
#    'immer',
#    'gute',
#    'Preise'],
#   'aspect': ['Preise'],
#   'position': [[27]],
#   'sentiment': ['Positive'],
#   'probs': [[0.02641950733959675, 0.017037007957696915, 0.956543505191803]],
#   'confidence': [0.956543505191803]},
#  {'sentence': 'Da bekommen wir fast alles Und wenn wir Hilfe benötigen dann ist immer jemand dader uns beraten kann Von mir die Sterne',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Da',
#    'bekommen',
#    'wir',
#    'fast',
#    'alles',
#    'Und',
#    'wenn',
#    'wir',
#    'Hilfe',
#    'benötigen',
#    'dann',
#    'ist',
#    'immer',
#    'jemand',
#    'dader',
#    'uns',
#    'beraten',
#    'kann',
#    'Von',
#    'mir',
#    'die',
#    'Sterne'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Gutes SortimentFaire Preise',
#   'IOB': ['O', 'B-ASP', 'I-ASP'],
#   'tokens': ['Gutes', 'SortimentFaire', 'Preise'],
#   'aspect': ['SortimentFaire Preise'],
#   'position': [[2, 3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.029707010835409164, 0.002562957815825939, 0.9677300453186035]],
#   'confidence': [0.9677300453186035]},
#  {'sentence': 'Der Baumarkt meiner Wahl',
#   'IOB': ['O', 'B-ASP', 'O', 'O'],
#   'tokens': ['Der', 'Baumarkt', 'meiner', 'Wahl'],
#   'aspect': ['Baumarkt'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00022944492229726166,
#     0.001974022015929222,
#     0.9977965354919434]],
#   'confidence': [0.9977965354919434]},
#  {'sentence': 'Hier findest Du immer das richtige',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hier', 'findest', 'Du', 'immer', 'das', 'richtige'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Dieser Baumarkt ist leider dermaßen unübersichtlich und unaufgeräumt Die Gänge wirken eng und dunkel und manche Abteilungen geben ein sehr chaotisches Bild ab bspw die MotorGartengeräteIn vielen Abteilungen liegen oftmals in den Regalen Produkte nicht richtig sortiert und sehen aus wie hingeschmissen oder die Bepreisung ist nicht eindeutig da mehrere ähnliche Produkte unsortiert beisammen liegen Gleichzeitig wirken Kartons bzw Artikel lieblos abgestellt und gestapeltWurde leider schon mehrfach enttäuscht und habe den Markt entnervt verlassen Da auch viel Zeit mit Suchen verbracht werden mussteFür mich ist es nicht nachvollziehbar dass Hornbach nicht mehr wert auf eine gutes Erscheinungsbild legt zumal sich in Bornheim die Zentrale befindetLeider echt kein Vergleich zum Ambiente und der Ordnung bei der Konkurrenz in Landau Besuche den Hornbach nur da dort die Preise teilweise um einiges besser sind',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Dieser',
#    'Baumarkt',
#    'ist',
#    'leider',
#    'dermaßen',
#    'unübersichtlich',
#    'und',
#    'unaufgeräumt',
#    'Die',
#    'Gänge',
#    'wirken',
#    'eng',
#    'und',
#    'dunkel',
#    'und',
#    'manche',
#    'Abteilungen',
#    'geben',
#    'ein',
#    'sehr',
#    'chaotisches',
#    'Bild',
#    'ab',
#    'bspw',
#    'die',
#    'MotorGartengeräteIn',
#    'vielen',
#    'Abteilungen',
#    'liegen',
#    'oftmals',
#    'in',
#    'den',
#    'Regalen',
#    'Produkte',
#    'nicht',
#    'richtig',
#    'sortiert',
#    'und',
#    'sehen',
#    'aus',
#    'wie',
#    'hingeschmissen',
#    'oder',
#    'die',
#    'Bepreisung',
#    'ist',
#    'nicht',
#    'eindeutig',
#    'da',
#    'mehrere',
#    'ähnliche',
#    'Produkte',
#    'unsortiert',
#    'beisammen',
#    'liegen',
#    'Gleichzeitig',
#    'wirken',
#    'Kartons',
#    'bzw',
#    'Artikel',
#    'lieblos',
#    'abgestellt',
#    'und',
#    'gestapeltWurde',
#    'leider',
#    'schon',
#    'mehrfach',
#    'enttäuscht',
#    'und',
#    'habe',
#    'den',
#    'Markt',
#    'entnervt',
#    'verlassen',
#    'Da',
#    'auch',
#    'viel',
#    'Zeit',
#    'mit',
#    'Suchen',
#    'verbracht',
#    'werden',
#    'mussteFür',
#    'mich',
#    'ist',
#    'es',
#    'nicht',
#    'nachvollziehbar',
#    'dass',
#    'Hornbach',
#    'nicht',
#    'mehr',
#    'wert',
#    'auf',
#    'eine',
#    'gutes',
#    'Erscheinungsbild',
#    'legt',
#    'zumal',
#    'sich',
#    'in',
#    'Bornheim',
#    'die',
#    'Zentrale',
#    'befindetLeider',
#    'echt',
#    'kein',
#    'Vergleich',
#    'zum',
#    'Ambiente',
#    'und',
#    'der',
#    'Ordnung',
#    'bei',
#    'der',
#    'Konkurrenz',
#    'in',
#    'Landau',
#    'Besuche',
#    'den',
#    'Hornbach',
#    'nur',
#    'da',
#    'dort',
#    'die',
#    'Preise',
#    'teilweise',
#    'um',
#    'einiges',
#    'besser',
#    'sind'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Gute Beratung elektro Abteilung',
#   'IOB': ['O', 'B-ASP', 'O', 'O'],
#   'tokens': ['Gute', 'Beratung', 'elektro', 'Abteilung'],
#   'aspect': ['Beratung'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00251395208761096, 0.008592763915657997, 0.9888933300971985]],
#   'confidence': [0.9888933300971985]},
#  {'sentence': 'Zuschnitt online bestellt und hat hervorragend geklappt Es wirkt etwas unaufgeräumt aber die Mitarbeiter sind sehr hilfsbereit und man findet spätestens mit deren Hilfe alles',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Zuschnitt',
#    'online',
#    'bestellt',
#    'und',
#    'hat',
#    'hervorragend',
#    'geklappt',
#    'Es',
#    'wirkt',
#    'etwas',
#    'unaufgeräumt',
#    'aber',
#    'die',
#    'Mitarbeiter',
#    'sind',
#    'sehr',
#    'hilfsbereit',
#    'und',
#    'man',
#    'findet',
#    'spätestens',
#    'mit',
#    'deren',
#    'Hilfe',
#    'alles'],
#   'aspect': ['Mitarbeiter'],
#   'position': [[14]],
#   'sentiment': ['Positive'],
#   'probs': [[0.002434016903862357, 0.005611088126897812, 0.9919548630714417]],
#   'confidence': [0.9919548630714417]},
#  {'sentence': 'Freundliches Personal',
#   'IOB': ['O', 'B-ASP'],
#   'tokens': ['Freundliches', 'Personal'],
#   'aspect': ['Personal'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00033871541381813586,
#     0.0008198918658308685,
#     0.9988414645195007]],
#   'confidence': [0.9988414645195007]},
#  {'sentence': 'Riesige Auswahl geschultes freundliches Personal alles unter einem Dach Hier findet man fast alles was das Handwerker Herz höher schlagen lässt',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Riesige',
#    'Auswahl',
#    'geschultes',
#    'freundliches',
#    'Personal',
#    'alles',
#    'unter',
#    'einem',
#    'Dach',
#    'Hier',
#    'findet',
#    'man',
#    'fast',
#    'alles',
#    'was',
#    'das',
#    'Handwerker',
#    'Herz',
#    'höher',
#    'schlagen',
#    'lässt'],
#   'aspect': ['Personal', 'Handwerker'],
#   'position': [[5], [17]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.00023935377248562872,
#     0.0005314460140652955,
#     0.9992291927337646],
#    [0.0002920690749306232, 0.001994116697460413, 0.9977138042449951]],
#   'confidence': [0.9992291927337646, 0.9977138042449951]},
#  {'sentence': 'Gutes und umfassendes Angebot Personal meist hilfreich Reservieren und abholen auch an Abholstation möglich',
#   'IOB': ['O',
#    'O',
#    'O',
#    'B-ASP',
#    'I-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Gutes',
#    'und',
#    'umfassendes',
#    'Angebot',
#    'Personal',
#    'meist',
#    'hilfreich',
#    'Reservieren',
#    'und',
#    'abholen',
#    'auch',
#    'an',
#    'Abholstation',
#    'möglich'],
#   'aspect': ['Angebot Personal', 'abholen'],
#   'position': [[4, 5], [10]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0003154583100695163, 0.003763281973078847, 0.99592125415802],
#    [0.0004812975530512631, 0.021845946088433266, 0.9776727557182312]],
#   'confidence': [0.99592125415802, 0.9776727557182312]},
#  {'sentence': 'Baumarkt für Handwerker',
#   'IOB': ['O', 'O', 'O'],
#   'tokens': ['Baumarkt', 'für', 'Handwerker'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Es gibt alle Werkzeuge',
#   'IOB': ['O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Es', 'gibt', 'alle', 'Werkzeuge'],
#   'aspect': ['Werkzeuge'],
#   'position': [[4]],
#   'sentiment': ['Positive'],
#   'probs': [[0.000625051383394748, 0.000624109641648829, 0.9987508058547974]],
#   'confidence': [0.9987508058547974]},
#  {'sentence': 'Große Auswahl Preise marktüblich ziemlich eng',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O'],
#   'tokens': ['Große', 'Auswahl', 'Preise', 'marktüblich', 'ziemlich', 'eng'],
#   'aspect': ['Preise'],
#   'position': [[3]],
#   'sentiment': ['Neutral'],
#   'probs': [[0.19393929839134216, 0.5664257407188416, 0.2396349310874939]],
#   'confidence': [0.5664257407188416]},
#  {'sentence': 'Mitarbeiter sehr hilfsbereit Programm an Leuchtmitteln für KFZ Fehlanzeige',
#   'IOB': ['B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Mitarbeiter',
#    'sehr',
#    'hilfsbereit',
#    'Programm',
#    'an',
#    'Leuchtmitteln',
#    'für',
#    'KFZ',
#    'Fehlanzeige'],
#   'aspect': ['Mitarbeiter'],
#   'position': [[1]],
#   'sentiment': ['Positive'],
#   'probs': [[0.04222401976585388, 0.002541070571169257, 0.9552348852157593]],
#   'confidence': [0.9552348852157593]},
#  {'sentence': 'Tanken billig Auto Waschen auch billig Alles gut Dankeschön',
#   'IOB': ['B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Tanken',
#    'billig',
#    'Auto',
#    'Waschen',
#    'auch',
#    'billig',
#    'Alles',
#    'gut',
#    'Dankeschön'],
#   'aspect': ['Tanken'],
#   'position': [[1]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0005910817417316139, 0.0009571014670655131, 0.998451828956604]],
#   'confidence': [0.998451828956604]},
#  {'sentence': 'Top Jeder hat Ahnung und ist hilfsbereit Riesensortiment Man bekommt wirklich alles da',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Top',
#    'Jeder',
#    'hat',
#    'Ahnung',
#    'und',
#    'ist',
#    'hilfsbereit',
#    'Riesensortiment',
#    'Man',
#    'bekommt',
#    'wirklich',
#    'alles',
#    'da'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Ein super großer Baumarkt viel Auswahl und nette hilfsbereite Mitarbeiter',
#   'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Ein',
#    'super',
#    'großer',
#    'Baumarkt',
#    'viel',
#    'Auswahl',
#    'und',
#    'nette',
#    'hilfsbereite',
#    'Mitarbeiter'],
#   'aspect': ['Baumarkt', 'Mitarbeiter'],
#   'position': [[4], [10]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.00039529320201836526,
#     0.0013509714044630527,
#     0.9982537627220154],
#    [0.00042499558185227215, 0.0009452550439164042, 0.9986298084259033]],
#   'confidence': [0.9982537627220154, 0.9986298084259033]},
#  {'sentence': 'Sehr sehr freundliche Mitarbeiterinnen locker flockig und kompetent Ein Grund mehr dort einzukaufen',
#   'IOB': ['O', 'O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Sehr',
#    'sehr',
#    'freundliche',
#    'Mitarbeiterinnen',
#    'locker',
#    'flockig',
#    'und',
#    'kompetent',
#    'Ein',
#    'Grund',
#    'mehr',
#    'dort',
#    'einzukaufen'],
#   'aspect': ['Mitarbeiterinnen'],
#   'position': [[4]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00029441379592753947,
#     0.0005793336895294487,
#     0.9991262555122375]],
#   'confidence': [0.9991262555122375]},
#  {'sentence': 'Bester und großer Baumarkt freundliche Mitarbeiter vor allem großen Lob an Herrn Reichert Dieser Baumarkt kaum zu vergleichen mit anderen Baumärkten Top',
#   'IOB': ['O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Bester',
#    'und',
#    'großer',
#    'Baumarkt',
#    'freundliche',
#    'Mitarbeiter',
#    'vor',
#    'allem',
#    'großen',
#    'Lob',
#    'an',
#    'Herrn',
#    'Reichert',
#    'Dieser',
#    'Baumarkt',
#    'kaum',
#    'zu',
#    'vergleichen',
#    'mit',
#    'anderen',
#    'Baumärkten',
#    'Top'],
#   'aspect': ['Baumarkt', 'Mitarbeiter'],
#   'position': [[4], [6]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0005305471713654697, 0.0004508676356635988, 0.9990185499191284],
#    [0.0006107680383138359, 0.0006532437400892377, 0.9987359642982483]],
#   'confidence': [0.9990185499191284, 0.9987359642982483]},
#  {'sentence': 'Kundenfreundliche Mitarbeiterhelfen beim Suchen',
#   'IOB': ['O', 'B-ASP', 'O', 'O'],
#   'tokens': ['Kundenfreundliche', 'Mitarbeiterhelfen', 'beim', 'Suchen'],
#   'aspect': ['Mitarbeiterhelfen'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.002653215080499649, 0.001790674403309822, 0.9955561757087708]],
#   'confidence': [0.9955561757087708]},
#  {'sentence': 'Der beste Baumarkt den ich je gesehen habe',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Der',
#    'beste',
#    'Baumarkt',
#    'den',
#    'ich',
#    'je',
#    'gesehen',
#    'habe'],
#   'aspect': ['Baumarkt'],
#   'position': [[3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0005063937860541046,
#     0.00038604874862357974,
#     0.9991075396537781]],
#   'confidence': [0.9991075396537781]},
#  {'sentence': 'Egal mit was man kommt es gibt immer einen Mitarbeiter der einem hilft und gegebenenfalls noch eine Idee hat',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Egal',
#    'mit',
#    'was',
#    'man',
#    'kommt',
#    'es',
#    'gibt',
#    'immer',
#    'einen',
#    'Mitarbeiter',
#    'der',
#    'einem',
#    'hilft',
#    'und',
#    'gegebenenfalls',
#    'noch',
#    'eine',
#    'Idee',
#    'hat'],
#   'aspect': ['Mitarbeiter'],
#   'position': [[10]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00043635733891278505, 0.001645216136239469, 0.997918426990509]],
#   'confidence': [0.997918426990509]},
#  {'sentence': 'Sehr große Auswahl',
#   'IOB': ['O', 'O', 'B-ASP'],
#   'tokens': ['Sehr', 'große', 'Auswahl'],
#   'aspect': ['Auswahl'],
#   'position': [[3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00034914538264274597,
#     0.0002659445453900844,
#     0.999384880065918]],
#   'confidence': [0.999384880065918]},
#  {'sentence': 'Riesiges Sortiment gute Beratung',
#   'IOB': ['O', 'B-ASP', 'O', 'B-ASP'],
#   'tokens': ['Riesiges', 'Sortiment', 'gute', 'Beratung'],
#   'aspect': ['Sortiment', 'Beratung'],
#   'position': [[2], [4]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.00038613079232163727, 0.000529379234649241, 0.99908447265625],
#    [0.00036431520129553974, 0.0009762498666532338, 0.9986593723297119]],
#   'confidence': [0.99908447265625, 0.9986593723297119]},
#  {'sentence': 'Freundliche Mitarbeiter gute Beratung Es wirkt leider alles ein bisschen in die Jahre gekommen',
#   'IOB': ['O',
#    'B-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Freundliche',
#    'Mitarbeiter',
#    'gute',
#    'Beratung',
#    'Es',
#    'wirkt',
#    'leider',
#    'alles',
#    'ein',
#    'bisschen',
#    'in',
#    'die',
#    'Jahre',
#    'gekommen'],
#   'aspect': ['Mitarbeiter', 'Beratung'],
#   'position': [[2], [4]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.004204527474939823, 0.0033929029013961554, 0.9924025535583496],
#    [0.01982235163450241, 0.008938096463680267, 0.9712395668029785]],
#   'confidence': [0.9924025535583496, 0.9712395668029785]},
#  {'sentence': 'Mein Favorit',
#   'IOB': ['O', 'O'],
#   'tokens': ['Mein', 'Favorit'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Alles top sortiert und wenn man fragen hat wird man auch gleich gut beraten',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Alles',
#    'top',
#    'sortiert',
#    'und',
#    'wenn',
#    'man',
#    'fragen',
#    'hat',
#    'wird',
#    'man',
#    'auch',
#    'gleich',
#    'gut',
#    'beraten'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Ich habe Ware am bestellt leider bis jetz keine Lieferung für Storno dauert noch tag',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Ich',
#    'habe',
#    'Ware',
#    'am',
#    'bestellt',
#    'leider',
#    'bis',
#    'jetz',
#    'keine',
#    'Lieferung',
#    'für',
#    'Storno',
#    'dauert',
#    'noch',
#    'tag'],
#   'aspect': ['Lieferung'],
#   'position': [[10]],
#   'sentiment': ['Negative'],
#   'probs': [[0.9986672401428223,
#     0.0007457495084963739,
#     0.0005870295572094619]],
#   'confidence': [0.9986672401428223]},
#  {'sentence': 'Hornbach mit Tankstelle Edeka dm Takko rofu Kinderland Deichmann alles an einem Fleck',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hornbach',
#    'mit',
#    'Tankstelle',
#    'Edeka',
#    'dm',
#    'Takko',
#    'rofu',
#    'Kinderland',
#    'Deichmann',
#    'alles',
#    'an',
#    'einem',
#    'Fleck'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Das beste Sortiment und die größte Auswahl weit und breit Nicht zu toppenMit dem Drive super bequem für Baustoffe Und dazu sehr preiswerte Tankstelle direkt dabei',
#   'IOB': ['O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O'],
#   'tokens': ['Das',
#    'beste',
#    'Sortiment',
#    'und',
#    'die',
#    'größte',
#    'Auswahl',
#    'weit',
#    'und',
#    'breit',
#    'Nicht',
#    'zu',
#    'toppenMit',
#    'dem',
#    'Drive',
#    'super',
#    'bequem',
#    'für',
#    'Baustoffe',
#    'Und',
#    'dazu',
#    'sehr',
#    'preiswerte',
#    'Tankstelle',
#    'direkt',
#    'dabei'],
#   'aspect': ['Sortiment', 'Auswahl', 'Drive', 'Tankstelle'],
#   'position': [[3], [7], [15], [24]],
#   'sentiment': ['Positive', 'Positive', 'Positive', 'Positive'],
#   'probs': [[0.0005423618713393807, 0.0002552728110458702, 0.9992024302482605],
#    [0.0005959743284620345, 0.00045874371426180005, 0.9989452958106995],
#    [0.0017767156241461635, 0.00745391147211194, 0.9907693266868591],
#    [0.001836771029047668, 0.00402451865375042, 0.9941387176513672]],
#   'confidence': [0.9992024302482605,
#    0.9989452958106995,
#    0.9907693266868591,
#    0.9941387176513672]},
#  {'sentence': 'Also ich bin an sich zufrieden mit hornbach Jedoch in Bereich Schreinerei ist KEIN Kompetentes Personal zu finden sie können weder Technische Zeichnungen noch Normale Zeichnungen lesen richtige Maße bestimmen und beraten Aus diesem Grund Sterne Verbesserung Vorschlag Schulung Mathematik Maße berechnen Zeichnungen Skizze Pläne lesen und verstehen Räumliches Verständnis logisches Denken verbessern der Kunden BeratungFalls dies nicht möglich ist bitte ich drum keine Werbung für Fachpersonal zu machen wen diese nicht gegeben ist im Bereich Schreiner Bornheim Landau',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Also',
#    'ich',
#    'bin',
#    'an',
#    'sich',
#    'zufrieden',
#    'mit',
#    'hornbach',
#    'Jedoch',
#    'in',
#    'Bereich',
#    'Schreinerei',
#    'ist',
#    'KEIN',
#    'Kompetentes',
#    'Personal',
#    'zu',
#    'finden',
#    'sie',
#    'können',
#    'weder',
#    'Technische',
#    'Zeichnungen',
#    'noch',
#    'Normale',
#    'Zeichnungen',
#    'lesen',
#    'richtige',
#    'Maße',
#    'bestimmen',
#    'und',
#    'beraten',
#    'Aus',
#    'diesem',
#    'Grund',
#    'Sterne',
#    'Verbesserung',
#    'Vorschlag',
#    'Schulung',
#    'Mathematik',
#    'Maße',
#    'berechnen',
#    'Zeichnungen',
#    'Skizze',
#    'Pläne',
#    'lesen',
#    'und',
#    'verstehen',
#    'Räumliches',
#    'Verständnis',
#    'logisches',
#    'Denken',
#    'verbessern',
#    'der',
#    'Kunden',
#    'BeratungFalls',
#    'dies',
#    'nicht',
#    'möglich',
#    'ist',
#    'bitte',
#    'ich',
#    'drum',
#    'keine',
#    'Werbung',
#    'für',
#    'Fachpersonal',
#    'zu',
#    'machen',
#    'wen',
#    'diese',
#    'nicht',
#    'gegeben',
#    'ist',
#    'im',
#    'Bereich',
#    'Schreiner',
#    'Bornheim',
#    'Landau'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Die Freundlichkeit des Personals lässt zu wünschen übrig wenn man zu einem Kunden zB sagt wenn sie das haben wollen bestellen Sie es im Internet welche Sprache ist das A möchte ich was verkaufen oder es sollte zu Hause bleiben und nicht so eine Betrieb arbeiten',
#   'IOB': ['O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Die',
#    'Freundlichkeit',
#    'des',
#    'Personals',
#    'lässt',
#    'zu',
#    'wünschen',
#    'übrig',
#    'wenn',
#    'man',
#    'zu',
#    'einem',
#    'Kunden',
#    'zB',
#    'sagt',
#    'wenn',
#    'sie',
#    'das',
#    'haben',
#    'wollen',
#    'bestellen',
#    'Sie',
#    'es',
#    'im',
#    'Internet',
#    'welche',
#    'Sprache',
#    'ist',
#    'das',
#    'A',
#    'möchte',
#    'ich',
#    'was',
#    'verkaufen',
#    'oder',
#    'es',
#    'sollte',
#    'zu',
#    'Hause',
#    'bleiben',
#    'und',
#    'nicht',
#    'so',
#    'eine',
#    'Betrieb',
#    'arbeiten'],
#   'aspect': ['Personals'],
#   'position': [[4]],
#   'sentiment': ['Negative'],
#   'probs': [[0.994971513748169, 0.0036604490596801043, 0.0013680707197636366]],
#   'confidence': [0.994971513748169]},
#  {'sentence': 'Top Arbeitgeber',
#   'IOB': ['O', 'B-ASP'],
#   'tokens': ['Top', 'Arbeitgeber'],
#   'aspect': ['Arbeitgeber'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0004879664920736104,
#     0.0006502752075903118,
#     0.9988617897033691]],
#   'confidence': [0.9988617897033691]},
#  {'sentence': 'Auch in Bornheim ist das Personal sehr Fachwissend und freundlich da steht man nicht lange ohne Beratung herum Super macht weiter so sehr zu empfehlen',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Auch',
#    'in',
#    'Bornheim',
#    'ist',
#    'das',
#    'Personal',
#    'sehr',
#    'Fachwissend',
#    'und',
#    'freundlich',
#    'da',
#    'steht',
#    'man',
#    'nicht',
#    'lange',
#    'ohne',
#    'Beratung',
#    'herum',
#    'Super',
#    'macht',
#    'weiter',
#    'so',
#    'sehr',
#    'zu',
#    'empfehlen'],
#   'aspect': ['Personal'],
#   'position': [[6]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0003590154810808599,
#     0.0009303277474828064,
#     0.9987106323242188]],
#   'confidence': [0.9987106323242188]},
#  {'sentence': 'Großer und gut ausgestatteter Baumarkt',
#   'IOB': ['O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Großer', 'und', 'gut', 'ausgestatteter', 'Baumarkt'],
#   'aspect': ['Baumarkt'],
#   'position': [[5]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0007452935096807778,
#     0.0007678374531678855,
#     0.9984868764877319]],
#   'confidence': [0.9984868764877319]},
#  {'sentence': 'Habe ich die Wahl zwischen Obi und Hagebau gehe ich nur zu HornbachDas hat sich auch nach Jahren nicht geändert Baumärkte die Kaffee Wein Zeitschriften Bücher Süßwaren etc verkaufen sind mir suspekt',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Habe',
#    'ich',
#    'die',
#    'Wahl',
#    'zwischen',
#    'Obi',
#    'und',
#    'Hagebau',
#    'gehe',
#    'ich',
#    'nur',
#    'zu',
#    'HornbachDas',
#    'hat',
#    'sich',
#    'auch',
#    'nach',
#    'Jahren',
#    'nicht',
#    'geändert',
#    'Baumärkte',
#    'die',
#    'Kaffee',
#    'Wein',
#    'Zeitschriften',
#    'Bücher',
#    'Süßwaren',
#    'etc',
#    'verkaufen',
#    'sind',
#    'mir',
#    'suspekt'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Nur noch Hornbach gute Beratung',
#   'IOB': ['O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Nur', 'noch', 'Hornbach', 'gute', 'Beratung'],
#   'aspect': ['Beratung'],
#   'position': [[5]],
#   'sentiment': ['Positive'],
#   'probs': [[0.004680689424276352, 0.006651478353887796, 0.9886677861213684]],
#   'confidence': [0.9886677861213684]},
#  {'sentence': 'Alle baustoffe sehr günstig und gutAlle Werzeug jahre garantie',
#   'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Alle',
#    'baustoffe',
#    'sehr',
#    'günstig',
#    'und',
#    'gutAlle',
#    'Werzeug',
#    'jahre',
#    'garantie'],
#   'aspect': ['baustoffe'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0007299486896954477, 0.000610233866609633, 0.9986598491668701]],
#   'confidence': [0.9986598491668701]},
#  {'sentence': 'Mitarbeiter die man immer fragen kannfinde ich großartig Ich habe nach Autozubehör gefragtgenau nach H Birnen Nachdem ich in verschiedenen Gängen gesucht habe in die ich geschickt wurde bin ich frustriert nach Hause gefahren',
#   'IOB': ['B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Mitarbeiter',
#    'die',
#    'man',
#    'immer',
#    'fragen',
#    'kannfinde',
#    'ich',
#    'großartig',
#    'Ich',
#    'habe',
#    'nach',
#    'Autozubehör',
#    'gefragtgenau',
#    'nach',
#    'H',
#    'Birnen',
#    'Nachdem',
#    'ich',
#    'in',
#    'verschiedenen',
#    'Gängen',
#    'gesucht',
#    'habe',
#    'in',
#    'die',
#    'ich',
#    'geschickt',
#    'wurde',
#    'bin',
#    'ich',
#    'frustriert',
#    'nach',
#    'Hause',
#    'gefahren'],
#   'aspect': ['Mitarbeiter'],
#   'position': [[1]],
#   'sentiment': ['Positive'],
#   'probs': [[0.007144906558096409, 0.005420990753918886, 0.9874340891838074]],
#   'confidence': [0.9874340891838074]},
#  {'sentence': 'Tolle Mitarbeiter marktleitung sehr nett und freundlich',
#   'IOB': ['O', 'B-ASP', 'I-ASP', 'O', 'O', 'O', 'O'],
#   'tokens': ['Tolle',
#    'Mitarbeiter',
#    'marktleitung',
#    'sehr',
#    'nett',
#    'und',
#    'freundlich'],
#   'aspect': ['Mitarbeiter marktleitung'],
#   'position': [[2, 3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00034197556669823825,
#     0.00046436095726676285,
#     0.9991937279701233]],
#   'confidence': [0.9991937279701233]},
#  {'sentence': 'Hornbach ist halt Hornbach super Service und freundliches Personal Online bestellen auf den nächsten Tag war aber alles schon am selben Tag abholbereit',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Hornbach',
#    'ist',
#    'halt',
#    'Hornbach',
#    'super',
#    'Service',
#    'und',
#    'freundliches',
#    'Personal',
#    'Online',
#    'bestellen',
#    'auf',
#    'den',
#    'nächsten',
#    'Tag',
#    'war',
#    'aber',
#    'alles',
#    'schon',
#    'am',
#    'selben',
#    'Tag',
#    'abholbereit'],
#   'aspect': ['Service', 'Personal'],
#   'position': [[6], [9]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0003734691417776048, 0.0018888204358518124, 0.9977377653121948],
#    [0.00031099485931918025, 0.001430797390639782, 0.9982581734657288]],
#   'confidence': [0.9977377653121948, 0.9982581734657288]},
#  {'sentence': 'Großer Baumarkt mit umfangreichen Sortiment und freundlichem Personal',
#   'IOB': ['O', 'O', 'O', 'O', 'B-ASP', 'O', 'O', 'B-ASP'],
#   'tokens': ['Großer',
#    'Baumarkt',
#    'mit',
#    'umfangreichen',
#    'Sortiment',
#    'und',
#    'freundlichem',
#    'Personal'],
#   'aspect': ['Sortiment', 'Personal'],
#   'position': [[5], [8]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0003537025477271527, 0.0015421528369188309, 0.9981040954589844],
#    [0.0005405253614298999, 0.0025112396106123924, 0.9969483017921448]],
#   'confidence': [0.9981040954589844, 0.9969483017921448]},
#  {'sentence': 'Wohl einer der größten Baumärkte in Deutschland Hab ich so selten gesehen Anstrengend ist hier die Rückgabe da sie in die Abteilungen gehen und die Sachen persönlich zurückbringen Aber bei der Menge sicher nachvollziehbar da auch kein Personal Lust auf die Massen haben Monster Drive In und große Auswahl Man muss die Sprache mögen aber vom Gemüt macht der Pfälzer einen doch freundlichen Eindruck Potenzial sicherlich beim Personal Dennoch besser als der Globus in der Nähe',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Wohl',
#    'einer',
#    'der',
#    'größten',
#    'Baumärkte',
#    'in',
#    'Deutschland',
#    'Hab',
#    'ich',
#    'so',
#    'selten',
#    'gesehen',
#    'Anstrengend',
#    'ist',
#    'hier',
#    'die',
#    'Rückgabe',
#    'da',
#    'sie',
#    'in',
#    'die',
#    'Abteilungen',
#    'gehen',
#    'und',
#    'die',
#    'Sachen',
#    'persönlich',
#    'zurückbringen',
#    'Aber',
#    'bei',
#    'der',
#    'Menge',
#    'sicher',
#    'nachvollziehbar',
#    'da',
#    'auch',
#    'kein',
#    'Personal',
#    'Lust',
#    'auf',
#    'die',
#    'Massen',
#    'haben',
#    'Monster',
#    'Drive',
#    'In',
#    'und',
#    'große',
#    'Auswahl',
#    'Man',
#    'muss',
#    'die',
#    'Sprache',
#    'mögen',
#    'aber',
#    'vom',
#    'Gemüt',
#    'macht',
#    'der',
#    'Pfälzer',
#    'einen',
#    'doch',
#    'freundlichen',
#    'Eindruck',
#    'Potenzial',
#    'sicherlich',
#    'beim',
#    'Personal',
#    'Dennoch',
#    'besser',
#    'als',
#    'der',
#    'Globus',
#    'in',
#    'der',
#    'Nähe'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Also ich muss sagen ich war beeindruckt wie professionelle unsere Reklamation bezüglich unserer Fliesen Lieferung abgearbeitet wurde Wir haben eine richtig große Menge Fiesen bestelltton Zuhause stellten wir fest eine Palette ist komplett falsch Die Dame bei Hornbach hat in Stunde alles geregelt Wir konnten noch am Samstagabend die Paletten tauschenDas nenne ich Service und EinsatzAuch die Mitarbeiter im Lager waren sehr hilfsbereitWenn es gut ist muss man das auchsagenDanke',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Also',
#    'ich',
#    'muss',
#    'sagen',
#    'ich',
#    'war',
#    'beeindruckt',
#    'wie',
#    'professionelle',
#    'unsere',
#    'Reklamation',
#    'bezüglich',
#    'unserer',
#    'Fliesen',
#    'Lieferung',
#    'abgearbeitet',
#    'wurde',
#    'Wir',
#    'haben',
#    'eine',
#    'richtig',
#    'große',
#    'Menge',
#    'Fiesen',
#    'bestelltton',
#    'Zuhause',
#    'stellten',
#    'wir',
#    'fest',
#    'eine',
#    'Palette',
#    'ist',
#    'komplett',
#    'falsch',
#    'Die',
#    'Dame',
#    'bei',
#    'Hornbach',
#    'hat',
#    'in',
#    'Stunde',
#    'alles',
#    'geregelt',
#    'Wir',
#    'konnten',
#    'noch',
#    'am',
#    'Samstagabend',
#    'die',
#    'Paletten',
#    'tauschenDas',
#    'nenne',
#    'ich',
#    'Service',
#    'und',
#    'EinsatzAuch',
#    'die',
#    'Mitarbeiter',
#    'im',
#    'Lager',
#    'waren',
#    'sehr',
#    'hilfsbereitWenn',
#    'es',
#    'gut',
#    'ist',
#    'muss',
#    'man',
#    'das',
#    'auchsagenDanke'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Netter großer Markt fast ALLES was das Herz begehrt',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Netter',
#    'großer',
#    'Markt',
#    'fast',
#    'ALLES',
#    'was',
#    'das',
#    'Herz',
#    'begehrt'],
#   'aspect': ['Markt'],
#   'position': [[3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.00031028350349515676,
#     0.0009566231747157872,
#     0.9987331032752991]],
#   'confidence': [0.9987331032752991]},
#  {'sentence': 'Hier finde ich alles',
#   'IOB': ['O', 'O', 'O', 'O'],
#   'tokens': ['Hier', 'finde', 'ich', 'alles'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Man sucht Parkett klappert zig Baumärkte ab entscheidet sich für einen im Hornbach um dann bei der Bestellung zu erfahren dass der Parkett nicht zu dem Preis wie ausgeschildert zu haben ist sondern um m gestiegen ist Sorry geht net',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Man',
#    'sucht',
#    'Parkett',
#    'klappert',
#    'zig',
#    'Baumärkte',
#    'ab',
#    'entscheidet',
#    'sich',
#    'für',
#    'einen',
#    'im',
#    'Hornbach',
#    'um',
#    'dann',
#    'bei',
#    'der',
#    'Bestellung',
#    'zu',
#    'erfahren',
#    'dass',
#    'der',
#    'Parkett',
#    'nicht',
#    'zu',
#    'dem',
#    'Preis',
#    'wie',
#    'ausgeschildert',
#    'zu',
#    'haben',
#    'ist',
#    'sondern',
#    'um',
#    'm',
#    'gestiegen',
#    'ist',
#    'Sorry',
#    'geht',
#    'net'],
#   'aspect': ['Parkett', 'Preis'],
#   'position': [[23], [27]],
#   'sentiment': ['Negative', 'Negative'],
#   'probs': [[0.9730020761489868, 0.02377549186348915, 0.0032224212773144245],
#    [0.997922956943512, 0.0014515144284814596, 0.0006255359039641917]],
#   'confidence': [0.9730020761489868, 0.997922956943512]},
#  {'sentence': 'Gut',
#   'IOB': ['O'],
#   'tokens': ['Gut'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Einfach toll und gute Produkte sowie die Preise',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Einfach',
#    'toll',
#    'und',
#    'gute',
#    'Produkte',
#    'sowie',
#    'die',
#    'Preise'],
#   'aspect': ['Preise'],
#   'position': [[8]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0004498374182730913,
#     0.0002921544946730137,
#     0.9992579817771912]],
#   'confidence': [0.9992579817771912]},
#  {'sentence': 'Große Auswahl und schön sortierter Markt',
#   'IOB': ['O', 'B-ASP', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Große', 'Auswahl', 'und', 'schön', 'sortierter', 'Markt'],
#   'aspect': ['Auswahl', 'Markt'],
#   'position': [[2], [6]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.00044468275154940784,
#     0.0003772721393033862,
#     0.9991779923439026],
#    [0.0006855905521661043, 0.002082271035760641, 0.9972321391105652]],
#   'confidence': [0.9991779923439026, 0.9972321391105652]},
#  {'sentence': 'Bisher der Markt bei dem ich für meine Kernsanierung alles gefunden habe Außnahme Türen Fliesen und LaminatBeratung war sehr freundlich und konnte mir bei meinen Anliegen sehr gut helfen',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
# ...
#    'euch',
#    'von',
#    'ganzem',
#    'Herzen',
#    'für',
#    'die',
#    'bevorstehende',
#    'Böller',
#    'Verkauf',
#    'Bendung',
#    'Ein',
#    'positives',
#    'Zeichen',
#    'in',
#    'die',
#    'richtige',
#    'Richtung',
#    'Dankeschön'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Großzügig und gut',
#   'IOB': ['O', 'O', 'O'],
#   'tokens': ['Großzügig', 'und', 'gut'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Der Hornbach überhaupt der erste Hornbach der Welt japahjajajiphijiphijiphijeWer also ein Hornbach Pilger ist sollte sich die Hornbach Stadt mal anschauenNur eins ungewöhnlich andere Produkte gibt es hier auch nicht Wie auch Hornbach hat ja alles',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Der',
#    'Hornbach',
#    'überhaupt',
#    'der',
#    'erste',
#    'Hornbach',
#    'der',
#    'Welt',
#    'japahjajajiphijiphijiphijeWer',
#    'also',
#    'ein',
#    'Hornbach',
#    'Pilger',
#    'ist',
#    'sollte',
#    'sich',
#    'die',
#    'Hornbach',
#    'Stadt',
#    'mal',
#    'anschauenNur',
#    'eins',
#    'ungewöhnlich',
#    'andere',
#    'Produkte',
#    'gibt',
#    'es',
#    'hier',
#    'auch',
#    'nicht',
#    'Wie',
#    'auch',
#    'Hornbach',
#    'hat',
#    'ja',
#    'alles'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Hier bekommt man alles für den Hausbau für Innen und außen sowie Gartenpflanzen',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Hier',
#    'bekommt',
#    'man',
#    'alles',
#    'für',
#    'den',
#    'Hausbau',
#    'für',
#    'Innen',
#    'und',
#    'außen',
#    'sowie',
#    'Gartenpflanzen'],
#   'aspect': ['Gartenpflanzen'],
#   'position': [[13]],
#   'sentiment': ['Positive'],
#   'probs': [[0.002991094021126628, 0.010961526073515415, 0.9860473871231079]],
#   'confidence': [0.9860473871231079]},
#  {'sentence': 'Große Auswahl färe Preise',
#   'IOB': ['O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Große', 'Auswahl', 'färe', 'Preise'],
#   'aspect': ['Preise'],
#   'position': [[4]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0013275090605020523,
#     0.0025762072764337063,
#     0.9960963129997253]],
#   'confidence': [0.9960963129997253]},
#  {'sentence': 'Da bekomme ich was ich brauche und zur Weihnachtszeit ist es super dort einzukaufen Bin sehr zufrieden',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Da',
#    'bekomme',
#    'ich',
#    'was',
#    'ich',
#    'brauche',
#    'und',
#    'zur',
#    'Weihnachtszeit',
#    'ist',
#    'es',
#    'super',
#    'dort',
#    'einzukaufen',
#    'Bin',
#    'sehr',
#    'zufrieden'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Große Auswahl',
#   'IOB': ['O', 'B-ASP'],
#   'tokens': ['Große', 'Auswahl'],
#   'aspect': ['Auswahl'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0005693609127774835,
#     0.0002343952946830541,
#     0.9991962313652039]],
#   'confidence': [0.9991962313652039]},
#  {'sentence': 'Man bekommt fast alles',
#   'IOB': ['O', 'O', 'O', 'O'],
#   'tokens': ['Man', 'bekommt', 'fast', 'alles'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Wirklich teuer',
#   'IOB': ['O', 'O'],
#   'tokens': ['Wirklich', 'teuer'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Ich have gedacht dass Sie haben viele Art aber leider haben sie nicht',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Ich',
#    'have',
#    'gedacht',
#    'dass',
#    'Sie',
#    'haben',
#    'viele',
#    'Art',
#    'aber',
#    'leider',
#    'haben',
#    'sie',
#    'nicht'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Schade nicht gefunden was gesuchtaber hornbach Ka gefunden',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'B-ASP', 'O', 'O'],
#   'tokens': ['Schade',
#    'nicht',
#    'gefunden',
#    'was',
#    'gesuchtaber',
#    'hornbach',
#    'Ka',
#    'gefunden'],
#   'aspect': ['hornbach'],
#   'position': [[6]],
#   'sentiment': ['Neutral'],
#   'probs': [[0.03831706568598747, 0.8015678524971008, 0.160115048289299]],
#   'confidence': [0.8015678524971008]},
#  {'sentence': 'Hauptzentrale mit allem was Hornbach zu bieten hat',
#   'IOB': ['B-ASP', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hauptzentrale',
#    'mit',
#    'allem',
#    'was',
#    'Hornbach',
#    'zu',
#    'bieten',
#    'hat'],
#   'aspect': ['Hauptzentrale'],
#   'position': [[1]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0005415055784396827,
#     0.0021322418469935656,
#     0.9973262548446655]],
#   'confidence': [0.9973262548446655]},
#  {'sentence': 'Wollte mir einen Transporter mieten aber das Personal sagte das ich keinen bekomme da es zulange gedauert hätte also das kann ich nicht verstehen also ein Tipp für zukünftige Kunden mietet euren Wagen woanders',
#   'IOB': ['O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Wollte',
#    'mir',
#    'einen',
#    'Transporter',
#    'mieten',
#    'aber',
#    'das',
#    'Personal',
#    'sagte',
#    'das',
#    'ich',
#    'keinen',
#    'bekomme',
#    'da',
#    'es',
#    'zulange',
#    'gedauert',
#    'hätte',
#    'also',
#    'das',
#    'kann',
#    'ich',
#    'nicht',
#    'verstehen',
#    'also',
#    'ein',
#    'Tipp',
#    'für',
#    'zukünftige',
#    'Kunden',
#    'mietet',
#    'euren',
#    'Wagen',
#    'woanders'],
#   'aspect': ['Transporter', 'Personal'],
#   'position': [[4], [8]],
#   'sentiment': ['Negative', 'Negative'],
#   'probs': [[0.8892099857330322, 0.09820672124624252, 0.012583295814692974],
#    [0.989600419998169, 0.00909840315580368, 0.001301236217841506]],
#   'confidence': [0.8892099857330322, 0.989600419998169]},
#  {'sentence': 'Hier gibt es alles zum bauen',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hier', 'gibt', 'es', 'alles', 'zum', 'bauen'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Alles bekommen',
#   'IOB': ['O', 'O'],
#   'tokens': ['Alles', 'bekommen'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Super',
#   'IOB': ['O'],
#   'tokens': ['Super'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Ein sog Verkäufer schickt die Kunden ein Regal Meter fort obwohl die Ware direkt hinter mir im Regal war Eine Einräumerin ist mit mir bis zum richtigen Platz gegangen Das ist Auskunft',
#   'IOB': ['O',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Ein',
#    'sog',
#    'Verkäufer',
#    'schickt',
#    'die',
#    'Kunden',
#    'ein',
#    'Regal',
#    'Meter',
#    'fort',
#    'obwohl',
#    'die',
#    'Ware',
#    'direkt',
#    'hinter',
#    'mir',
#    'im',
#    'Regal',
#    'war',
#    'Eine',
#    'Einräumerin',
#    'ist',
#    'mit',
#    'mir',
#    'bis',
#    'zum',
#    'richtigen',
#    'Platz',
#    'gegangen',
#    'Das',
#    'ist',
#    'Auskunft'],
#   'aspect': ['Verkäufer'],
#   'position': [[3]],
#   'sentiment': ['Negative'],
#   'probs': [[0.9978153705596924,
#     0.0007762390305288136,
#     0.0014083627611398697]],
#   'confidence': [0.9978153705596924]},
#  {'sentence': '',
#   'IOB': [],
#   'tokens': [],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Online gleiche Haustüren reserviert laut Reservierung auch Vorrätig Auto mit Kupplung und Anhänger mit Aufbau organisiert und zum vereinbarten Abholtermin km nach Landau Bornheim gefahren Hier erfährt man dann vor Ort dass nur eine der Haustüren da ist Sehr ärgerlich',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Online',
#    'gleiche',
#    'Haustüren',
#    'reserviert',
#    'laut',
#    'Reservierung',
#    'auch',
#    'Vorrätig',
#    'Auto',
#    'mit',
#    'Kupplung',
#    'und',
#    'Anhänger',
#    'mit',
#    'Aufbau',
#    'organisiert',
#    'und',
#    'zum',
#    'vereinbarten',
#    'Abholtermin',
#    'km',
#    'nach',
#    'Landau',
#    'Bornheim',
#    'gefahren',
#    'Hier',
#    'erfährt',
#    'man',
#    'dann',
#    'vor',
#    'Ort',
#    'dass',
#    'nur',
#    'eine',
#    'der',
#    'Haustüren',
#    'da',
#    'ist',
#    'Sehr',
#    'ärgerlich'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Super sortiert',
#   'IOB': ['O', 'O'],
#   'tokens': ['Super', 'sortiert'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Baumarkt halt',
#   'IOB': ['O', 'O'],
#   'tokens': ['Baumarkt', 'halt'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Zu wenig Auswahl',
#   'IOB': ['O', 'O', 'B-ASP'],
#   'tokens': ['Zu', 'wenig', 'Auswahl'],
#   'aspect': ['Auswahl'],
#   'position': [[3]],
#   'sentiment': ['Negative'],
#   'probs': [[0.9967619180679321,
#     0.0006885715411044657,
#     0.0025494140572845936]],
#   'confidence': [0.9967619180679321]},
#  {'sentence': 'Riesiges Sortiment eher teuer',
#   'IOB': ['O', 'B-ASP', 'O', 'O'],
#   'tokens': ['Riesiges', 'Sortiment', 'eher', 'teuer'],
#   'aspect': ['Sortiment'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.4720182716846466, 0.022184526547789574, 0.505797266960144]],
#   'confidence': [0.505797266960144]},
#  {'sentence': 'Gut sortierter Baumarkt Lose Schrauben Sortiment aller Art',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Gut',
#    'sortierter',
#    'Baumarkt',
#    'Lose',
#    'Schrauben',
#    'Sortiment',
#    'aller',
#    'Art'],
#   'aspect': ['Baumarkt'],
#   'position': [[3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0019757740665227175, 0.013438383117318153, 0.9845858216285706]],
#   'confidence': [0.9845858216285706]},
#  {'sentence': 'Selber bauen Hornbach hilft',
#   'IOB': ['O', 'O', 'O', 'O'],
#   'tokens': ['Selber', 'bauen', 'Hornbach', 'hilft'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Prima super Beratung immer das passende Werkzeug',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Prima',
#    'super',
#    'Beratung',
#    'immer',
#    'das',
#    'passende',
#    'Werkzeug'],
#   'aspect': ['Beratung', 'Werkzeug'],
#   'position': [[3], [7]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0003255971532780677, 0.0004710802750196308, 0.9992033839225769],
#    [0.00047251128125935793, 0.0014845742844045162, 0.9980429410934448]],
#   'confidence': [0.9992033839225769, 0.9980429410934448]},
#  {'sentence': 'Ein umwerfend gut bestückter Baumarkt',
#   'IOB': ['O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['Ein', 'umwerfend', 'gut', 'bestückter', 'Baumarkt'],
#   'aspect': ['Baumarkt'],
#   'position': [[5]],
#   'sentiment': ['Positive'],
#   'probs': [[0.000467727571958676, 0.0004407355154398829, 0.9990915060043335]],
#   'confidence': [0.9990915060043335]},
#  {'sentence': 'Gas station and car wash there are an alltime favoriteÜbersetzt von GoogleTankstelle und Autowaschanlage dort sind ein absoluter Favorit',
#   'IOB': ['B-ASP',
#    'I-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Gas',
#    'station',
#    'and',
#    'car',
#    'wash',
#    'there',
#    'are',
#    'an',
#    'alltime',
#    'favoriteÜbersetzt',
#    'von',
#    'GoogleTankstelle',
#    'und',
#    'Autowaschanlage',
#    'dort',
#    'sind',
#    'ein',
#    'absoluter',
#    'Favorit'],
#   'aspect': ['Gas station'],
#   'position': [[1, 2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0011911549372598529, 0.00869024358689785, 0.9901186227798462]],
#   'confidence': [0.9901186227798462]},
#  {'sentence': 'Gute Beratung großer Parkplatz große Auswahl Wenn man sich etwas drin auskennt und weiß was man braucht ist man schnell wieder raus',
#   'IOB': ['O',
#    'B-ASP',
#    'O',
#    'B-ASP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'tokens': ['Gute',
#    'Beratung',
#    'großer',
#    'Parkplatz',
#    'große',
#    'Auswahl',
#    'Wenn',
#    'man',
#    'sich',
#    'etwas',
#    'drin',
#    'auskennt',
#    'und',
#    'weiß',
#    'was',
#    'man',
#    'braucht',
#    'ist',
#    'man',
#    'schnell',
#    'wieder',
#    'raus'],
#   'aspect': ['Beratung', 'Parkplatz'],
#   'position': [[2], [4]],
#   'sentiment': ['Positive', 'Positive'],
#   'probs': [[0.0003623776719905436, 0.0032148021273314953, 0.9964228272438049],
#    [0.000388844171538949, 0.003681464120745659, 0.9959296584129333]],
#   'confidence': [0.9964228272438049, 0.9959296584129333]},
#  {'sentence': 'Schöner Laden Alles ist da',
#   'IOB': ['O', 'B-ASP', 'O', 'O', 'O'],
#   'tokens': ['Schöner', 'Laden', 'Alles', 'ist', 'da'],
#   'aspect': ['Laden'],
#   'position': [[2]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0006179893389344215,
#     0.0008622586610727012,
#     0.9985197186470032]],
#   'confidence': [0.9985197186470032]},
#  {'sentence': 'BAUMARKT EINKAUFSZENTRUM UND Boels Maschinenvermietung Kostenfreie Parkplätze',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'B-ASP'],
#   'tokens': ['BAUMARKT',
#    'EINKAUFSZENTRUM',
#    'UND',
#    'Boels',
#    'Maschinenvermietung',
#    'Kostenfreie',
#    'Parkplätze'],
#   'aspect': ['Parkplätze'],
#   'position': [[7]],
#   'sentiment': ['Positive'],
#   'probs': [[0.005243825726211071, 0.007947930134832859, 0.9868082404136658]],
#   'confidence': [0.9868082404136658]},
#  {'sentence': 'Sehr Kompetentes Personal und sehr hilfsbereit und freundlich',
#   'IOB': ['O', 'O', 'B-ASP', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Sehr',
#    'Kompetentes',
#    'Personal',
#    'und',
#    'sehr',
#    'hilfsbereit',
#    'und',
#    'freundlich'],
#   'aspect': ['Personal'],
#   'position': [[3]],
#   'sentiment': ['Positive'],
#   'probs': [[0.0002803885145112872,
#     0.0005076228990219533,
#     0.9992119073867798]],
#   'confidence': [0.9992119073867798]},
#  {'sentence': 'Hier gibt es alles was ein Baumarkt haben muss',
#   'IOB': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'tokens': ['Hier',
#    'gibt',
#    'es',
#    'alles',
#    'was',
#    'ein',
#    'Baumarkt',
#    'haben',
#    'muss'],
#   'aspect': [],
#   'position': [],
#   'sentiment': [],
#   'probs': [],
#   'confidence': []},
#  {'sentence': 'Da wir unser Haus renoviert haben waren wir die letzten Monate sozusagen Stammgäste hierIn den meisten Fällen sind wir sehr gut beraten worden',
#   'IOB': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ASP',
#    'O'],
#   'tokens': ['Da',
#    'wir',
#    'unser',
#    'Haus',
#    'renoviert',
#    'haben',
#    'waren',
#    'wir',
#    'die',
#    'letzten',
#    'Monate',
#    'sozusagen',
#    'Stammgäste',
#    'hierIn',
#    'den',
#    'meisten',
#    'Fällen',
#    'sind',
#    'wir',
#    'sehr',
#    'gut',
#    'beraten',
#    'worden'],
#   'aspect': ['beraten'],
#   'position': [[22]],
#   'sentiment': ['Positive'],
#   'probs': [[0.002332430798560381, 0.0060765305534005165, 0.9915909767150879]],
#   'confidence': [0.9915909767150879]},
#  ...]

# %%
# Dataframe from the list of dictionaries
atepc = pd.DataFrame(atepc_result)

# Extracting aspects and sentiments into a new dataframe
result = pd.DataFrame({'aspect': atepc['aspect'].sum(), 'sentiment': atepc['sentiment'].sum()})

# %%
# result

# %%
# Count of the number of times each aspect has been named
counts = result['aspect'].value_counts()

# New dataframe with the aspect, count_positive, and count_negative columns (left at 0 to be filled later)
result_counts = pd.DataFrame({'aspect': counts.index, 'count_positive': 0, 'count_negative': 0})

# Filling the count_positive and count_negative columns
for i, row in result_counts.iterrows():
    aspect = row['aspect']
    positive = (result['sentiment'] == 'Positive') & (result['aspect'] == aspect)
    negative = (result['sentiment'] == 'Negative') & (result['aspect'] == aspect)
    result_counts.at[i, 'count_positive'] = positive.sum()
    result_counts.at[i, 'count_negative'] = negative.sum()

# %%
result_counts.head()
# Out:
#         aspect  count_positive  count_negative
# 0     Personal              68              13
# 1     Baumarkt              64               4
# 2     Beratung              53               8
# 3  Mitarbeiter              52               8
# 4      Auswahl              48               2

# %%
# result_counts.to_csv("result_countsBORNHEIM.csv", index=False)

# %% [markdown]
# ### Some aspect seem to describe the same thing but are just written slightly different. Need to combine those to make a more accurate count:

# %%
# First replacing everything that can be broadly counted as "Customer Service"

# Dictionary that maps the aspects associated as "Customer Service"
mapping = {'Personal': 'Customer Service',
          'Beratung': 'Customer Service',
          'Mitarbeiter': 'Customer Service',
          'Service': 'Customer Service',
          'Mitarbeitern': 'Customer Service',
          'Kundenservice': 'Customer Service',
          'Mitarbeiterinnen': 'Customer Service',
          'Mitarbeiterin': 'Customer Service',
          'Berater': 'Customer Service',
          'beraten': 'Customer Service',
          'Verkäuferin': 'Customer Service',
          'Angestellte': 'Customer Service',
          'bedient': 'Customer Service',
          'Team': 'Customer Service',
          'Verkäufer': 'Customer Service',
          'Wartezeit': 'Customer Service',
          'personal': 'Customer Service',
          'warten': 'Customer Service',
          'Verpackungsservice': 'Customer Service',
          'Verkäufern': 'Customer Service',
          'Wartezeiten': 'Customer Service'}

# Replacing those aspects with "Customer Service"
result_counts['aspect'] = result_counts['aspect'].replace(mapping)

# Grouping by aspect and sum the count_positive and count_negative columns
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
# Repeating for everything that can be broadly counted as "Price"
mapping = {'Preise': 'Price',
          'Preis': 'Price',
          'Preisen': 'Price',
          'preislich': 'Price'}
result_counts['aspect'] = result_counts['aspect'].replace(mapping)
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
# Repeating for everything that can be broadly counted as "Market"
mapping = {'Baumarkt': 'Market',
          'Hornbach': 'Market',
          'Laden': 'Market',
          'Markt': 'Market',
          'Platz': 'Market',
          'Gänge': 'Market',
          'baumarkt': 'Market',
          'Geschäft': 'Market',
          'Atmosphäre': 'Market'}
result_counts['aspect'] = result_counts['aspect'].replace(mapping)
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
# Repeating for everything that can be broadly counted as "Product Line"
mapping = {'Auswahl': 'Product Line',
          'Sortiment': 'Product Line',
          'Angebot': 'Product Line',
          'Angebote': 'Product Line',
          'Qualität': 'Product Line',
          'Produkte': 'Product Line',
          'Waren': 'Product Line',
          'Produkten': 'Product Line',
          'AuswahlInsgesamt': 'Product Line',
           'Werkzeug': 'Product Line'}
result_counts['aspect'] = result_counts['aspect'].replace(mapping)
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
# Repeating for everything that can be broadly counted as "Parking"
mapping = {'Parkplätze': 'Parking',
          'Parkplatz': 'Parking',
          'Parkmöglichkeiten': 'Parking'}
result_counts['aspect'] = result_counts['aspect'].replace(mapping)
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
# Repeating for everything that can be broadly counted as "Gas station"
mapping = {'Tankstelle': 'Gas station',
          'Sprit': 'Gas station',
          'Tanken': 'Gas station',
          'tanken': 'Gas station',
          'Kraftstoff': 'Gas station',
          'Spritpreise': 'Gas station',
          'Tanke': 'Gas station'}
result_counts['aspect'] = result_counts['aspect'].replace(mapping)
result_grouped = result_counts.groupby('aspect').sum().reset_index()

# %%
result_grouped = result_grouped.sort_values(by='count_positive', ascending=False)

# %%
pd.set_option('display.max_rows', None)
result_grouped
# Out:
#                                  aspect  count_positive  count_negative
# 53                     Customer Service             235              53
# 130                              Market             114              11
# 175                        Product Line              94               5
# 174                               Price              54               2
# 90                          Gas station              26               0
# 153                             Parking              15               2
# 98                           Handwerker               6               1
# 126                               Leute               5               0
# 213                                Ware               4               0
# 1                              Abholung               4               1
# 0                          Abholservice               3               0
# 58                                Drive               3               1
# 41                               Blumen               3               0
# 149                                 Ort               3               0
# 61                              DriveIn               3               0
# 253                               place               3               0
# 257                            sortiert               2               0
# 182                           Schrauben               2               0
# 64                              Einkauf               2               0
# 138                     MitarbeiterSehr               2               0
# 239                                dort               2               0
# 112                             Hygiene               2               0
# 160                            Pflanzen               2               0
# 216                         Waschanlage               2               0
# 228                             abholen               2               0
# 170                     Preise Qualität               1               0
# 165                          PreisKeine               1               0
# 166            PreisLeistungsverhältnis               1               0
# 167      PreisLeistungsverhältnisOnline               1               0
# 168                  Preise Mitarbeiter               1               0
# 169                     Preise Personal               1               0
# 134                            Menschen               1               0
# 172                           Preisebei               1               0
# 173                    Preisen Personal               1               0
# 163                      Preis Garantie               1               0
# 121                     Küchenabteilung               1               0
# 119                    Kundenfreundlich               1               0
# 176                      Produktauswahl               1               0
# 180               Sanitärabteilungdanke               1               0
# 181                            Schampel               1               0
# 164                       Preis Service               1               0
# 125                     LaminatBeratung               1               0
# 123                           Ladesäule               1               0
# 162                   PlatzOriginalität               1               0
# 137                  MitarbeiterPositiv               1               0
# 133                            Material               1               2
# 139                   Mitarbeiterhelfen               1               0
# 140                    Mitarbeiterhilfe               1               0
# 141            MitarbeiterinnenBaumarkt               1               0
# 142                     Mitarbeiterteam               1               0
# 145                     Männerbetreuung               1               0
# 147                        Organisation               1               0
# 132                        Maschinisten               1               0
# 128                        Lieferzeiten               1               0
# 184                        ServiceDanke               1               0
# 155                        PersonalHier               1               0
# 156                         PersonalIst               1               0
# 157                          Personalda               1               0
# 158                         Personalhat               1               0
# 135            Mitarbeiter marktleitung               1               0
# 161                         PflanzenWir               1               0
# 154                        PersonalGehe               1               0
# 187                    Sortiment Preise               1               0
# 185                         ServiceSehr               1               0
# 245                            hornbach               1               1
# 230                        angestellter               1               0
# 231                        ausgestattet               1               0
# 233                             bastler               1               0
# 234                           baustoffe               1               0
# 235                          bauzubehör               1               0
# 237                            beratung               1               0
# 108                  HolzBodenabteilung               1               0
# 6                      Angebot Personal               1               0
# 109                       Holzzuschnitt               1               0
# 110   HornbachUmfangreichstes Sortiment               1               0
# 4                     AkkuHandschleifer               1               0
# 113                              Imbiss               1               0
# 2                             Abteilung               1               0
# 10                             Aquarien               1               0
# 42                            Brennholz               1               0
# 17                             Auflagen               1               0
# 93                              Gelände               1               0
# 16                               Aufbau               1               0
# 19                           Autowäsche               1               0
# 89                       Gartenpflanzen               1               0
# 14                Atmosphäre Parkplätze               1               0
# 20                                  Bad               1               0
# 13                          Arbeitgeber               1               0
# 12                               Arbeit               1               0
# 18                           Auswahlman               1               0
# 39                    Bestpreisgarantie               0               1
# 38                        Beschilderung               0               1
# 37               Beratungaber Verkäufer               0               1
# 236                              benzin               0               1
# 215                   Warenpräsentation               0               1
# 3                            Abwicklung               0               1
# 240                           geliefert               0               1
# 5                               Anfahrt               0               1
# 210                            Vorhänge               0               1
# 229                             angebot               0               1
# 32                  Bedienungsanleitung               0               1
# 31                            Bedienung               0               1
# 11                           Aquaristik               0               1
# 22                              Bauhaus               0               1
# 223                             Wohnung               0               0
# 15                    AtmosphäreAuswahl               0               1
# 224                      Zahlungssystem               0               1
# 225                            Zentrale               0               1
# 247                                mahn               0               1
# 232                                 bad               0               1
# 238                              corona               0               1
# 248                            material               0               1
# 29                             Baunarkt               0               1
# 56                          Dekoartikel               0               1
# 208                      Verkäuferinnen               0               1
# 95                               Gängen               0               1
# 152                             Parkett               0               1
# 151                              Parken               0               1
# 150                     Paketverfolgung               0               1
# 148                 Orientierungssystem               0               1
# 91                           Gasflasche               0               1
# 146                        OnlineHandel               0               1
# 92                             Gasgrill               0               0
# 144                             Muttern               0               0
# 143                         Modebutique               0               1
# 94                            GoogleHat               0               0
# 96                                Halle               0               1
# 87                         Gartencenter               0               0
# 97                          Halsbändern               0               1
# 136                MitarbeiterAnsonsten               0               1
# 129                         Limoservice               0               1
# 106                          High Light               0               1
# 127                           Lieferung               0               2
# 124                        Lagerhaltung               0               1
# 122                            Ladenvon               0               1
# 120                              Küchen               0               0
# 111                           Hornbachs               0               1
# 117                     Kassen Personal               0               1
# 88                          Gartenmöbel               0               1
# 159                           Personals               0               1
# 207                     Verkaufsberater               0               1
# 54                         Dach Fenster               0               0
# 43                           Buchenholz               0               1
# 44              Central OfficeÜbersetzt               0               0
# 203                Transportunternehmen               0               1
# 202                         Transporter               0               1
# 46                          Christbäume               0               1
# 49                               Corona               0               1
# 197                             Support               0               1
# 196                       Stufenplatten               0               1
# 194                         Steckmuffen               0               1
# 193                                Stab               0               1
# 116                              Kassen               0               1
# 75                          Fachberater               0               1
# 57                               Diesel               0               1
# 183                            Security               0               1
# 179                               Salat               0               1
# 178                      Rückabwicklung               0               1
# 177                              Regeln               0               1
# 68                             Eintritt               0               1
# 69                         Emailadresse               0               1
# 171                         Preise Ware               0               1
# 73                          Essen Essen               0               1
# 74                              Etikett               0               1
# 261                                  Öl               0               0

# %%
# result_grouped.to_csv('result_groupedBORNHEIM.csv', index=False)
